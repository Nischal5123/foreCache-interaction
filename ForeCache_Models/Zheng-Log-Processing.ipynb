# %%
def get_fields_from_vglstr(vglstr):
    encoding_str = vglstr.split(';')[1]
    encoding_str = encoding_str.split(':')[1]
    encodings = encoding_str.split(',')
    fields = []
    for encode in encodings:
        field = encode.split('-')[0]
        if field == '':
            continue
        fields.append(field)
    return fields

# %%
def get_fields_from_vglstr_updated(vglstr):
    encoding_str = vglstr.split(';')[1]
    encoding_str = encoding_str.split(':')[1]
    encodings = encoding_str.split(',')
    fields = ['None'] * 3
    for encode in encodings:
        field = encode.split('-')[0]
        if field == '':
            continue
        else:
            if "-x" in encode:
                fields[0]=field
            elif "-y" in encode:
                fields[1]=field
            else:
                fields[2]=field

    return fields

# %%
def get_action_reward(interaction):
    if interaction == "main chart changed because of clicking a field":
        action='click'
        reward=1
        state='Data_View'
    elif interaction == "specified chart":
        action='specified'
        reward=1
        state='Specified_View'
    elif interaction == "added chart to bookmark":
        action='bookmark'
        reward=10
        state='Top_Panel'
    elif interaction.startswith('mouseover'):
        action='mouse'
        reward=1
        state='Related_View'
    elif interaction.startswith('mouseout'):
        action='mouse'
        reward=1
        state='Related_View'
    else:
        action='configuring'
        reward=0.1
        state='Task_Panel'
    return action, reward, state

# %%
# def get_state(interaction):
#     if "field" in interaction:
#         state='Data_View'
#     elif "specified chart" in interaction:
#         state='Specified_View'
#     elif 'bookmark' in interaction:
#         state='Top_Panel'
#     elif 'related chart' in interaction:
#         state='Related_View'
#     elif 'typed' in interaction:
#         state='Task_Panel'
#     else:
#         state='Configuring'
#     return state

def get_state(interaction):
    if "field" in interaction:
        state='Foraging'
    elif "specified chart" in interaction:
        state='Sensemaking'
    elif 'bookmark' in interaction:
        state='Sensemaking'
    elif 'related chart' in interaction:
        state='Foraging'
    elif 'typed' in interaction:
        state='Navigation'
    else:
        state='Navigation'
    return state

# %%
def one_hot_encode_state(attributes):
    fieldnames = ['Title', 'US_Gross', 'Worldwide_Gross', 'US_DVD_Sales', 'Production_Budget', 'Release_Date', 'MPAA_Rating', 'Running_Time_min', 'Distributor', 'Source', 'Major_Genre', 'Creative_Type', 'Director', 'Rotten_Tomatoes_Rating', 'IMDB_Rating', 'IMDB_Votes', 'None']

    # Initialize a list of zeros with the length of fieldnames
    one_hot = [0] * len(attributes)

    # Set 1 at the index corresponding to each attribute in the fieldnames
    for idx in range(len(attributes)):
        index = fieldnames.index(attributes[idx])
        one_hot[idx] = index

    return one_hot

# %%
import os
processed_interactions_path = './data/zheng/processed_interactions/'
csv_files = os.listdir(processed_interactions_path)
len(csv_files)
# Out:
# 36

# %%
import os
import pandas as pd
from collections import Counter

user_interactions_path = './data/zheng/processed_csv/'
processed_interactions_path = './data/zheng/processed_interactions/'
csv_files = os.listdir(user_interactions_path)

fieldnames = ['Title', 'US_Gross', 'Worldwide_Gross', 'US_DVD_Sales', 'Production_Budget', 'Release_Date', 'MPAA_Rating', 'Running_Time_min', 'Distributor', 'Source', 'Major_Genre', 'Creative_Type', 'Director', 'Rotten_Tomatoes_Rating', 'IMDB_Rating', 'IMDB_Votes', 'None']

for csv_filename in csv_files:
    if csv_filename.endswith('p4_logs.csv'):
        print("Converting '{}'...".format(csv_filename))
        user_name = csv_filename.split('.')[0]
        print(os.path.join(user_interactions_path, csv_filename))

        df = pd.read_csv(os.path.join(user_interactions_path, csv_filename))
        print('Total size of interaction log', len(df))

        important_attributes=[]
        important_attributes_exact=[]
        for index, row in df.iterrows():
            value = row['Value']
            interaction= row['Interaction']
            try:
                attrs = get_fields_from_vglstr(value)
                if 'added chart to bookmark' in interaction:
                    important_attributes_exact.append(str(attrs))
                    for a in attrs:
                     important_attributes.append(a)
            except:
                pass
        print('Important attribute',important_attributes)
        important_attributes_counter = Counter(important_attributes)
        print('Important attribute exact',important_attributes_exact)
        important_attributes_exact_counter = Counter(important_attributes_exact)



        df_attributes = []
        df_user_index = []
        df_reward = []
        df_action = []
        df_state=[]
        df_high_state=[]

        for index, row in df.iterrows():
            df_user_index.append(index)
            value = row['Value']
            interaction= row['Interaction']
            try:
                attributes = get_fields_from_vglstr_updated(value)
                df_attributes.append(attributes)

                # Calculate reward based on common attributes between 'attributes' and 'important_attributes'
                reward = 0.1
                if important_attributes_exact_counter[str(attributes)]>1:
                    print('Exact Match')
                reward +=important_attributes_exact_counter[str(attributes)]*3
                for attribute in attributes:
                    reward += important_attributes_counter[attribute]


            except:
                df_attributes.append(['None','None','None'])
                reward=0.1
            action, _, _ = get_action_reward(interaction)
            df_action.append(action)
            df_reward.append(reward)
            df_state.append(one_hot_encode_state(df_attributes[-1]))
            df_high_state.append(get_state(interaction))

        df['Attribute'] = df_attributes
        df['Reward'] = df_reward
        df['Action'] = df_action
        df['State'] = df_state
        df['High-Level-State']=df_high_state

        df['User_Index'] = df.index  # Use the existing DataFrame index as User_Index
        df.set_index('User_Index', inplace=True)  # Set 'User_Index' as the index

        # Reset the index before saving to CSV
        df.reset_index(inplace=True)
        # Drop rows where 'Value' is empty
        df = df[df['Value'].notna()]
        # Drop rows where 'Interaction' contains 'typed in answer'
        df = df[~df['Interaction'].str.contains('typed in answer')]
         # Drop rows where 'Interaction' contains 'typed in answer'
        df = df[~df['Interaction'].str.contains('changed ptask ans')]

        df = df[~df['Interaction'].str.contains('main chart changed')]

        df = df[~df['Interaction'].str.contains('clicked on a field')]

        df = df[~df['Interaction'].str.contains('window')]

        df = df[~df['Interaction'].str.contains('study begins')]

        # Fix index
        df.reset_index(drop=True, inplace=True)

        # Reorder columns
        df = df[['User_Index', 'Interaction', 'Value', 'Time', 'Reward', 'Action', 'Attribute', 'State','High-Level-State']]

        processed_csv_path = os.path.join(processed_interactions_path, csv_filename)
        df.to_csv(processed_csv_path, index=False)  # Use index=False to avoid the "Unnamed: 0" column
# Out:
# Converting 'stu29_ade_p4_logs.csv'...
# ./data/zheng/processed_csv/stu29_ade_p4_logs.csv
# Total size of interaction log 2351
# Important attribute ['Major_Genre', 'Running_Time_min', 'Major_Genre', 'Rotten_Tomatoes_Rating', 'Running_Time_min', 'Distributor', 'Production_Budget', 'Creative_Type', 'Distributor', 'Production_Budget', 'Major_Genre', 'Source']
# Important attribute exact ["['Major_Genre', 'Running_Time_min']", "['Major_Genre', 'Rotten_Tomatoes_Rating', 'Running_Time_min']", "['Distributor', 'Production_Budget']", "['Creative_Type', 'Distributor', 'Production_Budget']", "['Major_Genre', 'Source']"]
# Converting 'stu26_ace_p4_logs.csv'...
# ./data/zheng/processed_csv/stu26_ace_p4_logs.csv
# Total size of interaction log 5315
# Important attribute ['IMDB_Rating', 'Major_Genre', 'Distributor', 'Source', 'Release_Date', 'Major_Genre', 'Running_Time_min', 'Major_Genre', 'Production_Budget']
# Important attribute exact ["['IMDB_Rating', 'Major_Genre']", "['Distributor', 'Source']", "['Release_Date']", "['Major_Genre', 'Running_Time_min']", "['Major_Genre', 'Production_Budget']"]
# Converting 'pro8_acf_p4_logs.csv'...
# ./data/zheng/processed_csv/pro8_acf_p4_logs.csv
# Total size of interaction log 999
# Important attribute ['Major_Genre', 'Release_Date', 'Major_Genre', 'Release_Date', 'US_Gross', 'Major_Genre', 'Release_Date', 'Worldwide_Gross', 'Major_Genre', 'Release_Date', 'Rotten_Tomatoes_Rating', 'Release_Date']
# Important attribute exact ["['Major_Genre', 'Release_Date']", "['Major_Genre', 'Release_Date', 'US_Gross']", "['Major_Genre', 'Release_Date', 'Worldwide_Gross']", "['Major_Genre', 'Release_Date', 'Rotten_Tomatoes_Rating']", "['Release_Date']"]
# Converting 'pro20_ade_p4_logs.csv'...
# ./data/zheng/processed_csv/pro20_ade_p4_logs.csv
# Total size of interaction log 3491
# Important attribute ['MPAA_Rating', 'Worldwide_Gross', 'Source', 'MPAA_Rating', 'Production_Budget', 'Major_Genre', 'Release_Date', 'Major_Genre', 'Production_Budget', 'Source', 'US_DVD_Sales', 'US_Gross']
# Important attribute exact ["['MPAA_Rating', 'Worldwide_Gross']", "['Source']", "['MPAA_Rating', 'Production_Budget']", "['Major_Genre', 'Release_Date']", "['Major_Genre', 'Production_Budget']", "['Source', 'US_DVD_Sales', 'US_Gross']"]
# Converting 'stu36_adf_p4_logs.csv'...
# ./data/zheng/processed_csv/stu36_adf_p4_logs.csv
# Total size of interaction log 1358
# Important attribute ['Release_Date', 'Running_Time_min', 'Production_Budget', 'Source', 'Worldwide_Gross', 'Major_Genre', 'US_DVD_Sales', 'Creative_Type', 'US_Gross', 'Worldwide_Gross', 'Creative_Type', 'Release_Date', 'US_Gross']
# Important attribute exact ["['Release_Date', 'Running_Time_min']", "['Production_Budget', 'Source', 'Worldwide_Gross']", "['Major_Genre', 'US_DVD_Sales']", "['Creative_Type', 'US_Gross', 'Worldwide_Gross']", "['Creative_Type', 'Release_Date', 'US_Gross']"]
# Converting 'stu21_ace_p4_logs.csv'...
# ./data/zheng/processed_csv/stu21_ace_p4_logs.csv
# Total size of interaction log 3234
# Important attribute ['Release_Date', 'Major_Genre', 'Creative_Type', 'Distributor', 'IMDB_Rating', 'Rotten_Tomatoes_Rating', 'IMDB_Votes', 'Rotten_Tomatoes_Rating']
# Important attribute exact ["['Release_Date']", "['Major_Genre']", "['Creative_Type']", "['Distributor']", "['IMDB_Rating', 'Rotten_Tomatoes_Rating']", "['IMDB_Votes', 'Rotten_Tomatoes_Rating']"]
# Converting 'pro15_ade_p4_logs.csv'...
# ./data/zheng/processed_csv/pro15_ade_p4_logs.csv
# Total size of interaction log 1034
# Important attribute ['Release_Date', 'Release_Date', 'US_Gross', 'Creative_Type', 'Running_Time_min', 'Production_Budget', 'Release_Date', 'Production_Budget', 'Rotten_Tomatoes_Rating']
# Important attribute exact ["['Release_Date']", "['Release_Date', 'US_Gross']", "['Creative_Type', 'Running_Time_min']", "['Production_Budget', 'Release_Date']", "['Production_Budget', 'Rotten_Tomatoes_Rating']"]
# Converting 'stu39_adf_p4_logs.csv'...
# ./data/zheng/processed_csv/stu39_adf_p4_logs.csv
# Total size of interaction log 2550
# Important attribute ['IMDB_Rating', 'Worldwide_Gross', 'Creative_Type', 'Running_Time_min', 'Worldwide_Gross', 'Creative_Type', 'Worldwide_Gross', 'Director', 'IMDB_Rating', 'Worldwide_Gross', 'Distributor', 'Production_Budget']
# Important attribute exact ["['IMDB_Rating', 'Worldwide_Gross']", "['Creative_Type', 'Running_Time_min', 'Worldwide_Gross']", "['Creative_Type', 'Worldwide_Gross']", "['Director', 'IMDB_Rating', 'Worldwide_Gross']", "['Distributor', 'Production_Budget']"]
# Converting 'stu37_adf_p4_logs.csv'...
# ./data/zheng/processed_csv/stu37_adf_p4_logs.csv
# Total size of interaction log 1455
# Important attribute ['US_DVD_Sales', 'US_Gross', 'Worldwide_Gross', 'IMDB_Rating', 'IMDB_Votes', 'IMDB_Rating', 'Rotten_Tomatoes_Rating', 'IMDB_Rating', 'Production_Budget', 'Creative_Type', 'Major_Genre', 'Major_Genre', 'Release_Date', 'US_Gross', 'Major_Genre', 'Release_Date', 'Worldwide_Gross']
# Important attribute exact ["['US_DVD_Sales', 'US_Gross', 'Worldwide_Gross']", "['IMDB_Rating', 'IMDB_Votes']", "['IMDB_Rating', 'Rotten_Tomatoes_Rating']", "['IMDB_Rating', 'Production_Budget']", "['Creative_Type', 'Major_Genre']", "['Major_Genre', 'Release_Date', 'US_Gross']", "['Major_Genre', 'Release_Date', 'Worldwide_Gross']"]
# Converting 'stu6_acf_p4_logs.csv'...
# ./data/zheng/processed_csv/stu6_acf_p4_logs.csv
# Total size of interaction log 3812
# Important attribute ['IMDB_Rating', 'Rotten_Tomatoes_Rating', 'US_DVD_Sales', 'Director', 'Production_Budget', 'Worldwide_Gross', 'Creative_Type', 'MPAA_Rating', 'Major_Genre', 'Distributor', 'Major_Genre', 'IMDB_Votes', 'MPAA_Rating', 'Major_Genre']
# Important attribute exact ["['IMDB_Rating', 'Rotten_Tomatoes_Rating', 'US_DVD_Sales']", "['Director', 'Production_Budget', 'Worldwide_Gross']", "['Creative_Type', 'MPAA_Rating', 'Major_Genre']", "['Distributor', 'Major_Genre']", "['IMDB_Votes', 'MPAA_Rating', 'Major_Genre']"]
# Converting 'pro31_adf_p4_logs.csv'...
# ./data/zheng/processed_csv/pro31_adf_p4_logs.csv
# Total size of interaction log 3390
# Important attribute ['Title', 'US_Gross', 'Major_Genre', 'Production_Budget', 'Production_Budget', 'Worldwide_Gross', 'IMDB_Rating', 'US_DVD_Sales', 'Major_Genre', 'MPAA_Rating', 'Major_Genre', 'Release_Date']
# Important attribute exact ["['Title', 'US_Gross']", "['Major_Genre', 'Production_Budget']", "['Production_Budget', 'Worldwide_Gross']", "['IMDB_Rating', 'US_DVD_Sales']", "['Major_Genre']", "['MPAA_Rating', 'Major_Genre', 'Release_Date']"]
# Converting 'stu13_acf_p4_logs.csv'...
# ./data/zheng/processed_csv/stu13_acf_p4_logs.csv
# Total size of interaction log 1209
# Important attribute ['Major_Genre', 'Production_Budget', 'Production_Budget', 'Source', 'Major_Genre', 'Rotten_Tomatoes_Rating', 'Rotten_Tomatoes_Rating', 'Source', 'Major_Genre', 'Source', 'Worldwide_Gross']
# Important attribute exact ["['Major_Genre', 'Production_Budget']", "['Production_Budget', 'Source']", "['Major_Genre', 'Rotten_Tomatoes_Rating']", "['Rotten_Tomatoes_Rating', 'Source']", "['Major_Genre', 'Source', 'Worldwide_Gross']"]
# Converting 'pro29_ace_p4_logs.csv'...
# ./data/zheng/processed_csv/pro29_ace_p4_logs.csv
# Total size of interaction log 3081
# Important attribute ['Production_Budget', 'Release_Date', 'Rotten_Tomatoes_Rating', 'Production_Budget', 'Release_Date', 'Running_Time_min', 'Production_Budget', 'Release_Date', 'US_Gross', 'Production_Budget', 'Rotten_Tomatoes_Rating', 'Release_Date', 'Rotten_Tomatoes_Rating']
# Important attribute exact ["['Production_Budget', 'Release_Date', 'Rotten_Tomatoes_Rating']", "['Production_Budget', 'Release_Date', 'Running_Time_min']", "['Production_Budget', 'Release_Date', 'US_Gross']", "['Production_Budget', 'Rotten_Tomatoes_Rating']", "['Release_Date', 'Rotten_Tomatoes_Rating']"]
# Converting 'stu38_acf_p4_logs.csv'...
# ./data/zheng/processed_csv/stu38_acf_p4_logs.csv
# Total size of interaction log 1159
# Important attribute ['Release_Date', 'MPAA_Rating', 'Distributor', 'Release_Date', 'Rotten_Tomatoes_Rating', 'US_Gross', 'Major_Genre', 'Source', 'US_DVD_Sales']
# Important attribute exact ["['Release_Date']", "['MPAA_Rating']", "['Distributor']", "['Release_Date', 'Rotten_Tomatoes_Rating', 'US_Gross']", "['Major_Genre', 'Source', 'US_DVD_Sales']"]
# Converting 'stu7_ade_p4_logs.csv'...
# ./data/zheng/processed_csv/stu7_ade_p4_logs.csv
# Total size of interaction log 1044
# Important attribute ['IMDB_Rating', 'Worldwide_Gross', 'Creative_Type', 'IMDB_Rating', 'Worldwide_Gross', 'IMDB_Rating', 'Release_Date', 'Worldwide_Gross', 'IMDB_Rating', 'IMDB_Votes', 'Worldwide_Gross', 'Creative_Type', 'Major_Genre', 'Production_Budget', 'Creative_Type', 'Worldwide_Gross', 'Creative_Type', 'MPAA_Rating', 'Release_Date']
# Important attribute exact ["['IMDB_Rating', 'Worldwide_Gross']", "['Creative_Type', 'IMDB_Rating', 'Worldwide_Gross']", "['IMDB_Rating', 'Release_Date', 'Worldwide_Gross']", "['IMDB_Rating', 'IMDB_Votes', 'Worldwide_Gross']", "['Creative_Type', 'Major_Genre', 'Production_Budget']", "['Creative_Type', 'Worldwide_Gross']", "['Creative_Type', 'MPAA_Rating', 'Release_Date']"]
# Converting 'stu31_ade_p4_logs.csv'...
# ./data/zheng/processed_csv/stu31_ade_p4_logs.csv
# Total size of interaction log 5107
# Important attribute ['Director', 'Distributor', 'Distributor', 'MPAA_Rating', 'MPAA_Rating', 'Production_Budget', 'MPAA_Rating', 'Running_Time_min', 'IMDB_Rating', 'Running_Time_min', 'IMDB_Rating', 'Rotten_Tomatoes_Rating']
# Important attribute exact ["['Director']", "['Distributor']", "['Distributor']", "['MPAA_Rating']", "['MPAA_Rating', 'Production_Budget']", "['MPAA_Rating', 'Running_Time_min']", "['IMDB_Rating', 'Running_Time_min']", "['IMDB_Rating', 'Rotten_Tomatoes_Rating']"]
# Converting 'pro13_ace_p4_logs.csv'...
# ./data/zheng/processed_csv/pro13_ace_p4_logs.csv
# Total size of interaction log 1186
# Important attribute ['Major_Genre', 'Rotten_Tomatoes_Rating', 'Release_Date', 'Rotten_Tomatoes_Rating', 'Production_Budget', 'Source', 'Creative_Type', 'Production_Budget', 'Source', 'Release_Date', 'Worldwide_Gross']
# Important attribute exact ["['Major_Genre', 'Rotten_Tomatoes_Rating']", "['Release_Date', 'Rotten_Tomatoes_Rating']", "['Production_Budget', 'Source']", "['Creative_Type', 'Production_Budget', 'Source']", "['Release_Date', 'Worldwide_Gross']"]
# Converting 'stu15_ade_p4_logs.csv'...
# ./data/zheng/processed_csv/stu15_ade_p4_logs.csv
# Total size of interaction log 2022
# Important attribute ['IMDB_Rating', 'Production_Budget', 'Production_Budget', 'Rotten_Tomatoes_Rating', 'Production_Budget', 'Worldwide_Gross', 'Production_Budget', 'US_Gross', 'Rotten_Tomatoes_Rating', 'Worldwide_Gross', 'IMDB_Rating', 'Worldwide_Gross']
# Important attribute exact ["['IMDB_Rating', 'Production_Budget']", "['Production_Budget', 'Rotten_Tomatoes_Rating']", "['Production_Budget', 'Worldwide_Gross']", "['Production_Budget', 'US_Gross']", "['Rotten_Tomatoes_Rating', 'Worldwide_Gross']", "['IMDB_Rating', 'Worldwide_Gross']"]
# Converting 'pro9_acf_p4_logs.csv'...
# ./data/zheng/processed_csv/pro9_acf_p4_logs.csv
# Total size of interaction log 1573
# Important attribute ['IMDB_Rating', 'Worldwide_Gross', 'Running_Time_min', 'Source', 'Worldwide_Gross', 'IMDB_Rating', 'IMDB_Votes', 'Production_Budget', 'Worldwide_Gross', 'IMDB_Rating', 'Production_Budget', 'Worldwide_Gross']
# Important attribute exact ["['IMDB_Rating', 'Worldwide_Gross']", "['Running_Time_min', 'Source', 'Worldwide_Gross']", "['IMDB_Rating', 'IMDB_Votes']", "['Production_Budget', 'Worldwide_Gross']", "['IMDB_Rating', 'Production_Budget', 'Worldwide_Gross']"]
# Converting 'stu30_adf_p4_logs.csv'...
# ./data/zheng/processed_csv/stu30_adf_p4_logs.csv
# Total size of interaction log 1132
# Important attribute ['Major_Genre', 'Release_Date', 'US_Gross', 'Major_Genre', 'Release_Date', 'Worldwide_Gross', 'Major_Genre', 'Release_Date', 'MPAA_Rating', 'Major_Genre', 'MPAA_Rating', 'Major_Genre', 'Worldwide_Gross', 'Major_Genre', 'Production_Budget', 'Worldwide_Gross', 'MPAA_Rating', 'Major_Genre', 'Worldwide_Gross']
# Important attribute exact ["['Major_Genre', 'Release_Date', 'US_Gross']", "['Major_Genre', 'Release_Date', 'Worldwide_Gross']", "['Major_Genre', 'Release_Date']", "['MPAA_Rating', 'Major_Genre']", "['MPAA_Rating', 'Major_Genre', 'Worldwide_Gross']", "['Major_Genre', 'Production_Budget', 'Worldwide_Gross']", "['MPAA_Rating', 'Major_Genre', 'Worldwide_Gross']"]
# Converting 'pro21_ade_p4_logs.csv'...
# ./data/zheng/processed_csv/pro21_ade_p4_logs.csv
# Total size of interaction log 5854
# Important attribute ['US_Gross', 'Worldwide_Gross', 'Creative_Type', 'Worldwide_Gross', 'Production_Budget', 'Worldwide_Gross', 'Distributor', 'Worldwide_Gross', 'Distributor', 'Production_Budget', 'Distributor', 'Production_Budget', 'Worldwide_Gross']
# Important attribute exact ["['US_Gross', 'Worldwide_Gross']", "['Creative_Type', 'Worldwide_Gross']", "['Production_Budget', 'Worldwide_Gross']", "['Distributor', 'Worldwide_Gross']", "['Distributor', 'Production_Budget']", "['Distributor', 'Production_Budget', 'Worldwide_Gross']"]
# Converting 'stu11_adf_p4_logs.csv'...
# ./data/zheng/processed_csv/stu11_adf_p4_logs.csv
# Total size of interaction log 2024
# Important attribute ['Major_Genre', 'Running_Time_min', 'Worldwide_Gross', 'Creative_Type', 'Worldwide_Gross', 'Creative_Type', 'US_DVD_Sales', 'Creative_Type', 'Production_Budget', 'Worldwide_Gross', 'Distributor', 'Production_Budget']
# Important attribute exact ["['Major_Genre', 'Running_Time_min', 'Worldwide_Gross']", "['Creative_Type', 'Worldwide_Gross']", "['Creative_Type', 'US_DVD_Sales']", "['Creative_Type', 'Production_Budget', 'Worldwide_Gross']", "['Distributor', 'Production_Budget']"]
# Converting 'pro18_adf_p4_logs.csv'...
# ./data/zheng/processed_csv/pro18_adf_p4_logs.csv
# Total size of interaction log 2161
# Important attribute ['MPAA_Rating', 'Distributor', 'Director', 'Title', 'Rotten_Tomatoes_Rating']
# Important attribute exact ["['MPAA_Rating']", "['Distributor']", "['Director']", "['Title']", "['Rotten_Tomatoes_Rating']"]
# Converting 'pro25_acf_p4_logs.csv'...
# ./data/zheng/processed_csv/pro25_acf_p4_logs.csv
# Total size of interaction log 664
# Important attribute ['IMDB_Rating', 'Source', 'Worldwide_Gross', 'Production_Budget', 'Source', 'Worldwide_Gross', 'Creative_Type', 'IMDB_Rating', 'Major_Genre', 'Creative_Type', 'Major_Genre', 'Rotten_Tomatoes_Rating', 'Creative_Type', 'Running_Time_min', 'Creative_Type', 'Release_Date']
# Important attribute exact ["['IMDB_Rating', 'Source', 'Worldwide_Gross']", "['Production_Budget', 'Source', 'Worldwide_Gross']", "['Creative_Type', 'IMDB_Rating', 'Major_Genre']", "['Creative_Type', 'Major_Genre', 'Rotten_Tomatoes_Rating']", "['Creative_Type', 'Running_Time_min']", "['Creative_Type', 'Release_Date']"]
# Converting 'stu17_ace_p4_logs.csv'...
# ./data/zheng/processed_csv/stu17_ace_p4_logs.csv
# Total size of interaction log 2771
# Important attribute ['Creative_Type', 'Source', 'Worldwide_Gross', 'Distributor', 'Source', 'Worldwide_Gross', 'IMDB_Rating', 'Running_Time_min', 'Source', 'Creative_Type', 'MPAA_Rating', 'Creative_Type', 'Creative_Type', 'Worldwide_Gross']
# Important attribute exact ["['Creative_Type', 'Source', 'Worldwide_Gross']", "['Distributor', 'Source', 'Worldwide_Gross']", "['IMDB_Rating', 'Running_Time_min', 'Source']", "['Creative_Type', 'MPAA_Rating']", "['Creative_Type']", "['Creative_Type', 'Worldwide_Gross']"]
# Converting 'stu3_acf_p4_logs.csv'...
# ./data/zheng/processed_csv/stu3_acf_p4_logs.csv
# Total size of interaction log 4251
# Important attribute ['Source', 'Major_Genre', 'MPAA_Rating', 'Major_Genre', 'Production_Budget', 'Major_Genre', 'Production_Budget', 'Distributor', 'Production_Budget', 'Distributor', 'Major_Genre']
# Important attribute exact ["['Source']", "['Major_Genre']", "['MPAA_Rating', 'Major_Genre', 'Production_Budget']", "['Major_Genre', 'Production_Budget']", "['Distributor', 'Production_Budget']", "['Distributor', 'Major_Genre']"]
# Converting 'stu25_ace_p4_logs.csv'...
# ./data/zheng/processed_csv/stu25_ace_p4_logs.csv
# Total size of interaction log 1130
# Important attribute ['Creative_Type', 'IMDB_Rating', 'Rotten_Tomatoes_Rating', 'IMDB_Rating', 'Rotten_Tomatoes_Rating', 'Director', 'Running_Time_min', 'Creative_Type', 'US_Gross', 'Worldwide_Gross', 'Source', 'US_Gross', 'Worldwide_Gross', 'Creative_Type', 'Source']
# Important attribute exact ["['Creative_Type', 'IMDB_Rating', 'Rotten_Tomatoes_Rating']", "['IMDB_Rating', 'Rotten_Tomatoes_Rating']", "['Director', 'Running_Time_min']", "['Creative_Type', 'US_Gross', 'Worldwide_Gross']", "['Source', 'US_Gross', 'Worldwide_Gross']", "['Creative_Type', 'Source']"]
# Converting 'pro5_adf_p4_logs.csv'...
# ./data/zheng/processed_csv/pro5_adf_p4_logs.csv
# Total size of interaction log 1953
# Important attribute ['Major_Genre', 'US_Gross', 'Major_Genre', 'Production_Budget', 'US_Gross', 'Major_Genre', 'Source', 'US_Gross', 'Creative_Type', 'IMDB_Rating', 'US_Gross', 'IMDB_Rating', 'Major_Genre', 'US_Gross', 'IMDB_Rating', 'Source', 'US_Gross', 'Major_Genre', 'US_Gross', 'Worldwide_Gross', 'Source', 'US_Gross', 'Worldwide_Gross']
# Important attribute exact ["['Major_Genre', 'US_Gross']", "['Major_Genre', 'Production_Budget', 'US_Gross']", "['Major_Genre', 'Source', 'US_Gross']", "['Creative_Type', 'IMDB_Rating', 'US_Gross']", "['IMDB_Rating', 'Major_Genre', 'US_Gross']", "['IMDB_Rating', 'Source', 'US_Gross']", "['Major_Genre', 'US_Gross', 'Worldwide_Gross']", "['Source', 'US_Gross', 'Worldwide_Gross']"]
# Converting 'pro23_acf_p4_logs.csv'...
# ./data/zheng/processed_csv/pro23_acf_p4_logs.csv
# Total size of interaction log 1642
# Important attribute ['Release_Date', 'MPAA_Rating', 'Release_Date', 'Running_Time_min', 'Source', 'US_DVD_Sales', 'MPAA_Rating', 'Source', 'Worldwide_Gross']
# Important attribute exact ["['Release_Date']", "['MPAA_Rating']", "['Release_Date', 'Running_Time_min']", "['Source', 'US_DVD_Sales']", "['MPAA_Rating', 'Source', 'Worldwide_Gross']"]
# Converting 'pro22_ade_p4_logs.csv'...
# ./data/zheng/processed_csv/pro22_ade_p4_logs.csv
# Total size of interaction log 1530
# Important attribute ['Creative_Type', 'Release_Date', 'Creative_Type', 'Major_Genre', 'Release_Date', 'Creative_Type', 'Major_Genre', 'Creative_Type', 'US_Gross', 'Worldwide_Gross', 'Creative_Type', 'IMDB_Votes', 'Rotten_Tomatoes_Rating']
# Important attribute exact ["['Creative_Type', 'Release_Date']", "['Creative_Type', 'Major_Genre', 'Release_Date']", "['Creative_Type', 'Major_Genre']", "['Creative_Type', 'US_Gross', 'Worldwide_Gross']", "['Creative_Type', 'IMDB_Votes', 'Rotten_Tomatoes_Rating']"]
# Converting 'stu24_ace_p4_logs.csv'...
# ./data/zheng/processed_csv/stu24_ace_p4_logs.csv
# Total size of interaction log 2619
# Important attribute ['Release_Date', 'Creative_Type', 'IMDB_Rating', 'US_Gross', 'Worldwide_Gross', 'IMDB_Rating', 'IMDB_Votes', 'Rotten_Tomatoes_Rating', 'IMDB_Rating', 'Rotten_Tomatoes_Rating', 'US_Gross', 'Worldwide_Gross', 'IMDB_Rating', 'IMDB_Votes']
# Important attribute exact ["['Release_Date']", "['Creative_Type']", "['IMDB_Rating', 'US_Gross', 'Worldwide_Gross']", "['IMDB_Rating', 'IMDB_Votes', 'Rotten_Tomatoes_Rating']", "['IMDB_Rating', 'Rotten_Tomatoes_Rating']", "['US_Gross', 'Worldwide_Gross']", "['IMDB_Rating', 'IMDB_Votes']"]
# Converting 'stu10_acf_p4_logs.csv'...
# ./data/zheng/processed_csv/stu10_acf_p4_logs.csv
# Total size of interaction log 4164
# Important attribute ['MPAA_Rating', 'Worldwide_Gross', 'Director', 'US_Gross', 'Worldwide_Gross', 'Director', 'IMDB_Rating', 'Rotten_Tomatoes_Rating', 'Director', 'Running_Time_min', 'Creative_Type', 'Director']
# Important attribute exact ["['MPAA_Rating', 'Worldwide_Gross']", "['Director', 'US_Gross', 'Worldwide_Gross']", "['Director', 'IMDB_Rating', 'Rotten_Tomatoes_Rating']", "['Director', 'Running_Time_min']", "['Creative_Type', 'Director']"]
# Converting 'pro3_ace_p4_logs.csv'...
# ./data/zheng/processed_csv/pro3_ace_p4_logs.csv
# Total size of interaction log 1143
# Important attribute ['Creative_Type', 'MPAA_Rating', 'Creative_Type', 'MPAA_Rating', 'Major_Genre', 'Distributor', 'IMDB_Rating', 'IMDB_Votes', 'Running_Time_min', 'IMDB_Rating', 'Production_Budget', 'US_Gross', 'Distributor', 'Title']
# Important attribute exact ["['Creative_Type', 'MPAA_Rating']", "['Creative_Type', 'MPAA_Rating', 'Major_Genre']", "['Distributor']", "['IMDB_Rating', 'IMDB_Votes', 'Running_Time_min']", "['IMDB_Rating', 'Production_Budget', 'US_Gross']", "['Distributor', 'Title']"]
# Converting 'stu4_ade_p4_logs.csv'...
# ./data/zheng/processed_csv/stu4_ade_p4_logs.csv
# Total size of interaction log 632
# Important attribute ['Creative_Type', 'MPAA_Rating', 'MPAA_Rating', 'Release_Date', 'Release_Date', 'Source', 'MPAA_Rating', 'Release_Date', 'US_Gross']
# Important attribute exact ["['Creative_Type']", "['MPAA_Rating']", "['MPAA_Rating', 'Release_Date']", "['Release_Date', 'Source']", "['MPAA_Rating', 'Release_Date', 'US_Gross']"]
# Converting 'pro24_adf_p4_logs.csv'...
# ./data/zheng/processed_csv/pro24_adf_p4_logs.csv
# Total size of interaction log 2047
# Important attribute ['Distributor', 'Creative_Type', 'Distributor', 'Release_Date', 'Director', 'Major_Genre', 'US_Gross', 'Worldwide_Gross', 'Major_Genre', 'Release_Date', 'Worldwide_Gross']
# Important attribute exact ["['Distributor']", "['Creative_Type', 'Distributor', 'Release_Date']", "['Director']", "['Major_Genre', 'US_Gross', 'Worldwide_Gross']", "['Major_Genre', 'Release_Date', 'Worldwide_Gross']"]
# Converting 'pro17_ace_p4_logs.csv'...
# ./data/zheng/processed_csv/pro17_ace_p4_logs.csv
# Total size of interaction log 3007
# Important attribute ['Major_Genre', 'Release_Date', 'Major_Genre', 'Release_Date', 'Rotten_Tomatoes_Rating', 'Major_Genre', 'Production_Budget', 'Production_Budget', 'Source', 'Director', 'IMDB_Rating']
# Important attribute exact ["['Major_Genre', 'Release_Date']", "['Major_Genre', 'Release_Date', 'Rotten_Tomatoes_Rating']", "['Major_Genre', 'Production_Budget']", "['Production_Budget', 'Source']", "['Director', 'IMDB_Rating']"]

# %%
df['High-Level-State'].unique()
# Out:
# array(['Foraging', 'Sensemaking', 'Navigation'], dtype=object)

# %%
import numpy as np

processed_interactions_path = './data/zheng/processed_interactions/'
csv_files = os.listdir(processed_interactions_path)

fieldnames = ['Title', 'US_Gross', 'Worldwide_Gross', 'US_DVD_Sales', 'Production_Budget', 'Release_Date', 'MPAA_Rating', 'Running_Time_min', 'Distributor', 'Source', 'Major_Genre', 'Creative_Type', 'Director', 'Rotten_Tomatoes_Rating', 'IMDB_Rating', 'IMDB_Votes', 'None']

for csv_filename in csv_files:
    if csv_filename.endswith('p4_logs.csv'):
        print("Converting '{}'...".format(csv_filename))

        df = pd.read_csv(os.path.join(processed_interactions_path, csv_filename))
        actions=[]
        for index in range(len(df) - 1):  # Iterate up to the second-to-last row
            current_state = np.array(eval(df['State'][index]))  # Convert string representation to list
            next_state = np.array(eval(df['State'][index + 1]))  # Convert string representation to list
            action=''
            if next_state[0] != current_state[0]:
                action = 'modify-x'
            if next_state[1] != current_state[1]:
                action = 'modify-y'
            if next_state[2] != current_state[2]:
                action = 'modify-z'
            if next_state[1] != current_state[1] and next_state[2] != current_state[2]:
                action = 'modify-y-z'
            if next_state[0] != current_state[0] and next_state[2] != current_state[2]:
                action = 'modify-x-z'
            if next_state[0] != current_state[0] and next_state[1] != current_state[1]:
                action = 'modify-x-y'
            if next_state[0] == current_state[0] and next_state[1] == current_state[1] and next_state[2] == current_state[2]:
                action = 'same'
            if next_state[0] != current_state[0] and next_state[1] != current_state[1] and next_state[2] != current_state[2]:
                action = 'modify-x-y-z'
            actions.append(action)
            # current_action = current_state - next_state
            # df.at[index, 'Action'] = str(list(current_action))  # Convert the NumPy array back to a list and store as a string
        actions.append('same')
        df['Action']=actions


    # Save the modified DataFrame
    df.to_csv(os.path.join(processed_interactions_path, csv_filename), index=False)
# Out:
# Converting 'stu29_ade_p4_logs.csv'...
# Converting 'stu26_ace_p4_logs.csv'...
# Converting 'pro8_acf_p4_logs.csv'...
# Converting 'pro20_ade_p4_logs.csv'...
# Converting 'stu36_adf_p4_logs.csv'...
# Converting 'stu21_ace_p4_logs.csv'...
# Converting 'pro15_ade_p4_logs.csv'...
# Converting 'stu39_adf_p4_logs.csv'...
# Converting 'stu37_adf_p4_logs.csv'...
# Converting 'stu6_acf_p4_logs.csv'...
# Converting 'pro31_adf_p4_logs.csv'...
# Converting 'stu13_acf_p4_logs.csv'...
# Converting 'pro29_ace_p4_logs.csv'...
# Converting 'stu38_acf_p4_logs.csv'...
# Converting 'stu7_ade_p4_logs.csv'...
# Converting 'stu31_ade_p4_logs.csv'...
# Converting 'pro13_ace_p4_logs.csv'...
# Converting 'stu15_ade_p4_logs.csv'...
# Converting 'pro9_acf_p4_logs.csv'...
# Converting 'stu30_adf_p4_logs.csv'...
# Converting 'pro21_ade_p4_logs.csv'...
# Converting 'stu11_adf_p4_logs.csv'...
# Converting 'pro18_adf_p4_logs.csv'...
# Converting 'pro25_acf_p4_logs.csv'...
# Converting 'stu17_ace_p4_logs.csv'...
# Converting 'stu3_acf_p4_logs.csv'...
# Converting 'stu25_ace_p4_logs.csv'...
# Converting 'pro5_adf_p4_logs.csv'...
# Converting 'pro23_acf_p4_logs.csv'...
# Converting 'pro22_ade_p4_logs.csv'...
# Converting 'stu24_ace_p4_logs.csv'...
# Converting 'stu10_acf_p4_logs.csv'...
# Converting 'pro3_ace_p4_logs.csv'...
# Converting 'stu4_ade_p4_logs.csv'...
# Converting 'pro24_adf_p4_logs.csv'...
# Converting 'pro17_ace_p4_logs.csv'...
