# %%
# imMens results

import matplotlib.pyplot as plt

# Updated data based on the new results
strategies = ['Random',
  'Greedy',
  'WSLS',
  'Q-Learning',
  'Reinforce',
  'SARSA',
  'Actor-Critic',
  'Bayesian',
  'Momentum',
  'HMM']

# Updating the values with the new results for Greedy, Q-Learning, Reinforce, SARSA, Actor-Critic, Bayesian, and HMM
values = [
  [0.2, 0.19, 0.2, 0.2, 0.2, 0.19, 0.2, 0.21, 0.19],  # Random (no change)
   [0.425, 0.47, 0.5, 0.505, 0.465, 0.445, 0.465, 0.435, 0.485],  # Greedy (no change)
  [0.33, 0.33, 0.33, 0.33, 0.33, 0.32, 0.33, 0.31, 0.31],  # WSLS (no change)
  [0.66, 0.660, 0.655, 0.675, 0.695, 0.695, 0.710, 0.705, 0.730],  # Q-Learning (updated)
  [0.675, 0.685, 0.690, 0.710, 0.670, 0.695, 0.690, 0.640, 0.655],  # Reinforce (updated)
  [0.645, 0.650, 0.690, 0.660, 0.660, 0.665, 0.710, 0.670, 0.740],  # SARSA (updated)
  [0.610, 0.605, 0.690, 0.710, 0.720, 0.725, 0.730, 0.680, 0.680],  # Actor-Critic (updated)
  [0.64, 0.64, 0.645, 0.64, 0.635, 0.615, 0.63, 0.590, 0.585],  # Bayesian (updated)
  [0.33, 0.3, 0.35, 0.37, 0.38, 0.34, 0.41, 0.4, 0.51],  # Momentum (no change)
  [0.64, 0.64, 0.635, 0.635, 0.640, 0.635, 0.635, 0.645, 0.620]  # HMM (updated)
]

# X-axis percentages and labels
x_labels = ['10%', '20%', '30%', '40%', '50%', '60%', '70%', '80%', '90%']
markers = ['o', 's', '^', 'D', 'x', 'p', '*', '+']

plt.figure(figsize=(8, 6))

# Plotting the data
for i, strategy in enumerate(strategies):
    plt.plot(values[i], marker=markers[i % len(markers)], label=strategy)

plt.xlabel('Percentage of data used for training', fontsize=15)
plt.ylabel('Accuracy (%)', fontsize=15)
plt.xticks(range(len(x_labels)), x_labels, fontsize=13)  # Set custom x-axis ticks and labels with increased font size
# plt.yticks(fontsize=13)  # Increase Y-axis tick font size
# Set y-axis limits from 0 to 1 and y-ticks at 0.1 intervals
plt.ylim(0, 1)
plt.yticks([i/10 for i in range(0, 11)], fontsize=13)  # Set Y-axis ticks at 0.1 intervals

plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fancybox=True, shadow=True, ncol=1, fontsize=15)
plt.grid(axis='y')

# Save the plot as an SVG file
plt.savefig("tableau_accuracy_all_updated.svg", format='svg', bbox_inches='tight')

# %%
# imMens results

import matplotlib.pyplot as plt

# Updated data based on the new results
strategies = [
  'Greedy',
  'Q-Learning',
  'Bayesian',
  'Momentum',
  'HMM']

# Updating the values with the new results for Greedy, Q-Learning, Reinforce, SARSA, Actor-Critic, Bayesian, and HMM
values = [
   [0.425, 0.47, 0.5, 0.505, 0.465, 0.445, 0.465, 0.435, 0.485],  # Greedy (no change)
  [0.66, 0.660, 0.655, 0.675, 0.695, 0.695, 0.710, 0.705, 0.730],  # Q-Learning (updated)
  [0.64, 0.64, 0.645, 0.64, 0.635, 0.615, 0.63, 0.590, 0.585],  # Bayesian (updated)
  [0.33, 0.3, 0.35, 0.37, 0.38, 0.34, 0.41, 0.4, 0.51],  # Momentum (no change)
  [0.64, 0.64, 0.635, 0.635, 0.640, 0.635, 0.635, 0.645, 0.620]  # HMM (updated)
]
# X-axis percentages and labels
x_labels = ['10%', '20%', '30%', '40%', '50%', '60%', '70%', '80%', '90%']
# markers = ['o', 's', '^', 'D', 'x', 'p', '*', '+']
markers = ['s', 'o', '+', 'H', '^']

plt.figure(figsize=(8, 6))

for i, strategy in enumerate(strategies):
    plt.plot(values[i], marker=markers[i % len(markers)], label=strategy)

plt.xlabel('Percentage of data used for training', fontsize=15)
plt.ylabel('Accuracy (%)', fontsize=15)
plt.xticks(range(len(x_labels)), x_labels, fontsize=13)  # Set custom x-axis ticks and labels with increased font size
# plt.yticks(fontsize=13)  # Increase Y-axis tick font size
# Set y-axis limits from 0 to 1 and y-ticks at 0.1 intervals
plt.ylim(0, 1)
plt.yticks([i/10 for i in range(0, 11)], fontsize=13)  # Set Y-axis ticks at 0.1 intervals

plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fancybox=True, shadow=True, ncol=1, fontsize=15)
plt.grid(axis='y')

# Save the plot as an SVG file
plt.savefig("imMens_short.svg", format='svg', bbox_inches='tight')
