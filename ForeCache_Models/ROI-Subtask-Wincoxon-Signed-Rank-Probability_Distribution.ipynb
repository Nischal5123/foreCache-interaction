# %%
import glob
import pandas as pd
import numpy as np
import environment2
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'
from collections import defaultdict
from scipy.stats import mannwhitneyu
from scipy.stats import ttest_ind
from scipy.stats import wilcoxon
from statsmodels.tsa.stattools import adfuller
import pymannkendall as mk
import statistics

# %%
env = environment2.environment2()
user_list_2D = env.user_list_2D

# %%
user_list_2D[0]
# Out:
# 'data/NDSI-2D\\taskname_ndsi-2d-task_userid_3abeecbe-327a-441e-be2a-0dd3763c1d45.csv'

# %%
fileNames2D=['data/NDSI-2D\\taskname_ndsi-2d-task_userid_3abeecbe-327a-441e-be2a-0dd3763c1d45.csv',
 'data/NDSI-2D\\taskname_ndsi-2d-task_userid_44968286-f204-4ad6-a9b5-d95b38e97866.csv',
 'data/NDSI-2D\\taskname_ndsi-2d-task_userid_6d49fab8-273b-4a91-948b-ecd14556b049.csv',
 'data/NDSI-2D\\taskname_ndsi-2d-task_userid_72a8d170-77ae-400e-b2a5-de9e1d33a714.csv',
 'data/NDSI-2D\\taskname_ndsi-2d-task_userid_733a1ac5-0b01-485e-9b29-ac33932aa240.csv']

# %%
fileNames2D=user_list_2D

# %%
fileNames2D
# Out:
# array(['data/NDSI-2D\\taskname_ndsi-2d-task_userid_3abeecbe-327a-441e-be2a-0dd3763c1d45.csv',
#        'data/NDSI-2D\\taskname_ndsi-2d-task_userid_44968286-f204-4ad6-a9b5-d95b38e97866.csv',
#        'data/NDSI-2D\\taskname_ndsi-2d-task_userid_6d49fab8-273b-4a91-948b-ecd14556b049.csv',
#        'data/NDSI-2D\\taskname_ndsi-2d-task_userid_72a8d170-77ae-400e-b2a5-de9e1d33a714.csv',
#        'data/NDSI-2D\\taskname_ndsi-2d-task_userid_733a1ac5-0b01-485e-9b29-ac33932aa240.csv',
#        'data/NDSI-2D\\taskname_ndsi-2d-task_userid_7d014c75-453b-4188-9e4e-fb086984896a.csv',
#        'data/NDSI-2D\\taskname_ndsi-2d-task_userid_82316e37-1117-4663-84b4-ddb6455c83b2.csv',
#        'data/NDSI-2D\\taskname_ndsi-2d-task_userid_8b544d24-3274-4bb0-9719-fd2bccc87b02.csv',
#        'data/NDSI-2D\\taskname_ndsi-2d-task_userid_8bf5b71b-dfd4-403f-8791-06427b26ccaf.csv',
#        'data/NDSI-2D\\taskname_ndsi-2d-task_userid_93be0a02-3f7a-46c9-b526-aa956ed00856.csv',
#        'data/NDSI-2D\\taskname_ndsi-2d-task_userid_954edb7c-4eae-47ab-9338-5c5c7eccac2d.csv',
#        'data/NDSI-2D\\taskname_ndsi-2d-task_userid_a6aab5f5-fdb6-41df-9fc6-221d70f8c6e8.csv',
#        'data/NDSI-2D\\taskname_ndsi-2d-task_userid_ac5b65d7-f260-4534-9fae-d998b726ed32.csv',
#        'data/NDSI-2D\\taskname_ndsi-2d-task_userid_bc9f9425-e867-4876-a5d9-791229916767.csv',
#        'data/NDSI-2D\\taskname_ndsi-2d-task_userid_bda49380-37ad-41c5-a109-7fa198a7691a.csv',
#        'data/NDSI-2D\\taskname_ndsi-2d-task_userid_cd3ef507-e3e9-4edb-9222-90a69a9bf272.csv',
#        'data/NDSI-2D\\taskname_ndsi-2d-task_userid_d6555293-35c7-4c27-b522-38d67d2d1b1a.csv',
#        'data/NDSI-2D\\taskname_ndsi-2d-task_userid_da52acdd-3cea-483c-86e5-2c2740d371aa.csv',
#        'data/NDSI-2D\\taskname_ndsi-2d-task_userid_e4221e48-0930-40db-af3c-f4de1ed87582.csv',
#        'data/NDSI-2D\\taskname_ndsi-2d-task_userid_ff56863b-0710-4a58-ad22-4bf2889c9bc0.csv'],
#       dtype='<U82')

# %%
def get_ROISubset(data):
    roi_subset=[]
    subset=0
    for i in range(len(data)):
        if data["State"][i]=='Answering':
            data["State"][i]='Sensemaking'
        if data['State'][i]=='Sensemaking':
            if (i < (len(data) - 1)) and data['State'][i+1]!= 'Sensemaking':
                roi_subset.append(subset)
                subset=subset+1
            else:
                roi_subset.append(subset)
        else:
            roi_subset.append(subset)
    return roi_subset

# %%
from collections import defaultdict
def get_probabilities(dataframe):
    dataframe['high-level-action']=np.zeros(len(dataframe))
    probabilities=[]
    map=dict()
    # print(dataframe.head(5))
    states=['Sensemaking','Foraging','Navigation']
    actions=['change','same']
    for state in states:
      for action in actions:
        map[state+action]=0


    current_state=dataframe['State'][0]
    for i in range(1,len(dataframe)):
      if dataframe["State"][i]=='Answering':
        dataframe["State"][i]='Sensemaking'
      if dataframe["State"][i]== current_state:
        dataframe["high-level-action"][i-1]="same"
      else:
        dataframe["high-level-action"][i-1]="change"
      current_state=dataframe["State"][i]
    dataframe["high-level-action"][len(dataframe)-1]="same"
    for i in range(len(dataframe)):
      if dataframe['State'][i]=="Navigation":
        map[str(dataframe['State'][i]+dataframe['high-level-action'][i])] += 1
        probs = (map[str(dataframe['State'][i]+dataframe['high-level-action'][i])])/(map['Navigationchange']  + map['Navigationsame'])

      elif dataframe['State'][i]=="Foraging":
        map[str(dataframe['State'][i]+dataframe['high-level-action'][i])] += 1
        probs = (map[str(dataframe['State'][i]+dataframe['high-level-action'][i])])/(map['Foragingchange'] + map['Foragingsame'])

      else:
        map[str(dataframe['State'][i]+dataframe['high-level-action'][i])] += 1
        probs = (map[str(dataframe['State'][i]+dataframe['high-level-action'][i])])/(map['Sensemakingchange'] + map['Sensemakingsame'])
      probabilities.append(probs)
    dataframe['probabilities']=probabilities
    return dataframe, map

# %%
class StationarityTests:
    def __init__(self, significance=.05):
        self.SignificanceLevel = significance
        self.pValue = None
        self.isStationary = None
        self.trend= None
    def Mann_Whitney_U_Test(self,timeseries_X,timeseries_Y):
        #check normality
        # result1 =shapiro(timeseries_X)
        # result2 =shapiro(timeseries_Y)
        # px=result1.pvalue
        # py=result2.pvalue

        # if px < self.SignificanceLevel and py < self.SignificanceLevel:
        #     print("X Y not normal",px,py)
        # else:
        #     print("Normal",px,py)
        #return ttest_ind(timeseries_X, timeseries_Y)

        return mannwhitneyu(timeseries_X, timeseries_Y,alternative='two-sided')

    def Wilcoxon_Test(self,timeseries_X, timeseries_Y):

        return wilcoxon(timeseries_X, timeseries_Y)

    def ADF_Stationarity_Test(self, timeseries, printResults = True):
      #Dickey-Fuller test:
      adfTest = adfuller(timeseries, autolag='AIC')

      self.pValue = adfTest[1]

      if (self.pValue<self.SignificanceLevel):
          self.isStationary = True
      else:
          self.isStationary = False

      if printResults:
          dfResults = pd.Series(adfTest[0:4], index=['ADF Test Statistic','P-Value','# Lags Used','# Observations Used'])
          #Add Critical Values
          for key,value in adfTest[4].items():
              dfResults['Critical Value (%s)'%key] = value
          print('Augmented Dickey-Fuller Test Results:')
          print(dfResults)

    def Mann_Kendall_Stationarity_Test(self, timeseries, printResults = True):
      #Mann Kendall Trend Test:
      mktTest = mk.original_test(timeseries,self.SignificanceLevel)

      self.pValue = mktTest[2]
      self.trend= mktTest[0]
      self.isStationary = mktTest[1]

      if printResults:
          dfResults = pd.Series(mktTest[0:3], index=['Trend Type','Stationarity','P-Value'])
          #Add Critical Values
          for key,value in mktTest[3].items():
              dfResults['Critical Value (%s)'%key] = value
          print('Mann Kendall Trend Test:')
          print(dfResults)

# %%
user=[]
roi_cycle=[]
all_states=[]
result=[]


output_dataframe=pd.DataFrame(columns=['User','ROI_Cycle','State','Result'])
for u in fileNames2D:
  print("###########################",u)
  index=[]

  all_dfs=[]
  maps=[]
  df = pd.read_csv(u)
  u=u.lstrip('data/NDSI-2D\\taskname_ndsi-2d-task_')
  #u=u.lstrip('data/NDSI-3D\\taskname_ndsi-3d-task_')
  u=u.rstrip('.csv')



  #df['ROI_Cycle']=get_ROISubset(df)
  df['ROI_Cycle']=get_ROISubset(df)
  states=["Sensemaking",'Foraging','Navigation']
  serieses=np.empty(shape=(len(df.ROI_Cycle.unique()),len(states)),dtype=object)
  for k in df.ROI_Cycle.unique():
    dfs,mappings=get_probabilities((df.loc[df['ROI_Cycle'] == k]).reset_index(drop=True))
    for j in range(len(states)):

        state_df=dfs.loc[(dfs['State'] == states[j])]
        state_df.reset_index(inplace=True)

        same_probs=[]
        for indx in range(len(state_df)):
              if state_df['high-level-action'][indx]=='same':
                  same_probs.append(state_df['probabilities'][indx])
              else:
                  same_probs.append(1-state_df['probabilities'][indx])

        serieses[k][j]=same_probs

  for id in range(serieses.shape[1]):
      combinations=[]
      for first_cycle in range(serieses.shape[0]):
          for cycle in range(serieses.shape[0]):
            if first_cycle != cycle and list([first_cycle, cycle]) not in combinations and list(reversed([first_cycle, cycle])) not in combinations:
              print("Roi Cycles: #######################",[first_cycle,cycle]," ########State######## ",states[id])
              #for final dataframe
              all_states.append(states[id])
              user.append(u)
              roi_cycle.append([first_cycle,cycle])
              combinations.append([first_cycle,cycle])
              x=list(serieses[first_cycle][id])
              y=list(serieses[cycle][id])
              print("Initial Length: ",len(x),len(y))

              if len(x) == 0:
                x = [0.5] * len(y)
              elif len(y) == 0:
                y = [0.5]* len(x)
              else:
                  print(" ")

              # if len(y) < len(x):
              #  y = y + statistics.median(x) * (len(x) - len(y))
              # elif len(x) < len(y):
              #  x = x + statistics.median(y) * (len(y) - len(x))
              # else:
              #     print("\n")

              if  (len(x)>2 or len(y)>2):
                        sTest_state = StationarityTests()
                        trend=sTest_state.Mann_Whitney_U_Test(x, y)
                        print("State is: ", states[id], "  MWUT Result Non-Stationarity:  ", trend.pvalue < 0.05, trend.pvalue)
                        result.append(trend.pvalue < 0.05)
              else :
                         print("State is: ", states[id], "  MWUT Result is:  ","Not Enough Data")
                         result.append('NED')
            else:
                print("already calculated")

output_dataframe['User']=user
output_dataframe['Result']=result
output_dataframe['State']=all_states
output_dataframe['ROI_Cycle']=roi_cycle
# Out:
# ########################### data/NDSI-2D\taskname_ndsi-2d-task_userid_3abeecbe-327a-441e-be2a-0dd3763c1d45.csv
# already calculated
# already calculated
# already calculated
# ########################### data/NDSI-2D\taskname_ndsi-2d-task_userid_44968286-f204-4ad6-a9b5-d95b38e97866.csv
# already calculated
# Roi Cycles: ####################### [0, 1]  ########State########  Sensemaking
# Initial Length:  3 5
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [0, 2]  ########State########  Sensemaking
# Initial Length:  3 1
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [0, 3]  ########State########  Sensemaking
# Initial Length:  3 1
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [0, 4]  ########State########  Sensemaking
# Initial Length:  3 1
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [0, 5]  ########State########  Sensemaking
# Initial Length:  3 4
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [0, 6]  ########State########  Sensemaking
# Initial Length:  3 0
# State is:  Sensemaking   MWUT Result Non-Stationarity:   True 0.04685417760387376
# already calculated
# already calculated
# Roi Cycles: ####################### [1, 2]  ########State########  Sensemaking
# Initial Length:  5 1
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [1, 3]  ########State########  Sensemaking
# Initial Length:  5 1
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [1, 4]  ########State########  Sensemaking
# Initial Length:  5 1
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [1, 5]  ########State########  Sensemaking
# Initial Length:  5 4
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [1, 6]  ########State########  Sensemaking
# Initial Length:  5 0
# State is:  Sensemaking   MWUT Result Non-Stationarity:   True 0.003976751709788651
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [2, 3]  ########State########  Sensemaking
# Initial Length:  1 1
#
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [2, 4]  ########State########  Sensemaking
# Initial Length:  1 1
#
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [2, 5]  ########State########  Sensemaking
# Initial Length:  1 4
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [2, 6]  ########State########  Sensemaking
# Initial Length:  1 0
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [3, 4]  ########State########  Sensemaking
# Initial Length:  1 1
#
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [3, 5]  ########State########  Sensemaking
# Initial Length:  1 4
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [3, 6]  ########State########  Sensemaking
# Initial Length:  1 0
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [4, 5]  ########State########  Sensemaking
# Initial Length:  1 4
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [4, 6]  ########State########  Sensemaking
# Initial Length:  1 0
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [5, 6]  ########State########  Sensemaking
# Initial Length:  4 0
# State is:  Sensemaking   MWUT Result Non-Stationarity:   True 0.013123806784370716
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [0, 1]  ########State########  Foraging
# Initial Length:  4 1
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.2356799134290376
# Roi Cycles: ####################### [0, 2]  ########State########  Foraging
# Initial Length:  4 3
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.8254979107046321
# Roi Cycles: ####################### [0, 3]  ########State########  Foraging
# Initial Length:  4 2
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.583882420770365
# Roi Cycles: ####################### [0, 4]  ########State########  Foraging
# Initial Length:  4 1
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.2356799134290376
# Roi Cycles: ####################### [0, 5]  ########State########  Foraging
# Initial Length:  4 12
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.3990751965482372
# Roi Cycles: ####################### [0, 6]  ########State########  Foraging
# Initial Length:  4 1
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 1.0
# already calculated
# already calculated
# Roi Cycles: ####################### [1, 2]  ########State########  Foraging
# Initial Length:  1 3
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.3457785861511603
# Roi Cycles: ####################### [1, 3]  ########State########  Foraging
# Initial Length:  1 2
#
# State is:  Foraging   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [1, 4]  ########State########  Foraging
# Initial Length:  1 1
#
# State is:  Foraging   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [1, 5]  ########State########  Foraging
# Initial Length:  1 12
#
# State is:  Foraging   MWUT Result Non-Stationarity:   True 0.01943655266572564
# Roi Cycles: ####################### [1, 6]  ########State########  Foraging
# Initial Length:  1 1
#
# State is:  Foraging   MWUT Result is:   Not Enough Data
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [2, 3]  ########State########  Foraging
# Initial Length:  3 2
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.746885633390364
# Roi Cycles: ####################### [2, 4]  ########State########  Foraging
# Initial Length:  3 1
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.3457785861511603
# Roi Cycles: ####################### [2, 5]  ########State########  Foraging
# Initial Length:  3 12
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.2722535810629988
# Roi Cycles: ####################### [2, 6]  ########State########  Foraging
# Initial Length:  3 1
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 1.0
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [3, 4]  ########State########  Foraging
# Initial Length:  2 1
#
# State is:  Foraging   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [3, 5]  ########State########  Foraging
# Initial Length:  2 12
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.13416918012812584
# Roi Cycles: ####################### [3, 6]  ########State########  Foraging
# Initial Length:  2 1
#
# State is:  Foraging   MWUT Result is:   Not Enough Data
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [4, 5]  ########State########  Foraging
# Initial Length:  1 12
#
# State is:  Foraging   MWUT Result Non-Stationarity:   True 0.01943655266572564
# Roi Cycles: ####################### [4, 6]  ########State########  Foraging
# Initial Length:  1 1
#
# State is:  Foraging   MWUT Result is:   Not Enough Data
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [5, 6]  ########State########  Foraging
# Initial Length:  12 1
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 1.0
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [0, 1]  ########State########  Navigation
# Initial Length:  5 5
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.15793931050013044
# Roi Cycles: ####################### [0, 2]  ########State########  Navigation
# Initial Length:  5 8
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.08933928480473514
# Roi Cycles: ####################### [0, 3]  ########State########  Navigation
# Initial Length:  5 10
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.3170543186363255
# Roi Cycles: ####################### [0, 4]  ########State########  Navigation
# Initial Length:  5 12
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.26508419607192646
# Roi Cycles: ####################### [0, 5]  ########State########  Navigation
# Initial Length:  5 4
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.07961580146011343
# Roi Cycles: ####################### [0, 6]  ########State########  Navigation
# Initial Length:  5 4
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.8668152851274225
# already calculated
# already calculated
# Roi Cycles: ####################### [1, 2]  ########State########  Navigation
# Initial Length:  5 8
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.6537973076475477
# Roi Cycles: ####################### [1, 3]  ########State########  Navigation
# Initial Length:  5 10
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.281837888967578
# Roi Cycles: ####################### [1, 4]  ########State########  Navigation
# Initial Length:  5 12
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.3057237160511609
# Roi Cycles: ####################### [1, 5]  ########State########  Navigation
# Initial Length:  5 4
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.26017490098354834
# Roi Cycles: ####################### [1, 6]  ########State########  Navigation
# Initial Length:  5 4
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.2807126652684958
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [2, 3]  ########State########  Navigation
# Initial Length:  8 10
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.1338976644125384
# Roi Cycles: ####################### [2, 4]  ########State########  Navigation
# Initial Length:  8 12
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.09187497473476884
# Roi Cycles: ####################### [2, 5]  ########State########  Navigation
# Initial Length:  8 4
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.14455438900361467
# Roi Cycles: ####################### [2, 6]  ########State########  Navigation
# Initial Length:  8 4
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.24873563102963925
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [3, 4]  ########State########  Navigation
# Initial Length:  10 12
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.8388668080105661
# Roi Cycles: ####################### [3, 5]  ########State########  Navigation
# Initial Length:  10 4
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.09548464951169999
# Roi Cycles: ####################### [3, 6]  ########State########  Navigation
# Initial Length:  10 4
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.5966435837393289
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [4, 5]  ########State########  Navigation
# Initial Length:  12 4
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.0960607528677921
# Roi Cycles: ####################### [4, 6]  ########State########  Navigation
# Initial Length:  12 4
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.485917397384225
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [5, 6]  ########State########  Navigation
# Initial Length:  4 4
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.12154795634938084
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# ########################### data/NDSI-2D\taskname_ndsi-2d-task_userid_6d49fab8-273b-4a91-948b-ecd14556b049.csv
# already calculated
# Roi Cycles: ####################### [0, 1]  ########State########  Sensemaking
# Initial Length:  1 2
#
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [0, 2]  ########State########  Sensemaking
# Initial Length:  1 1
#
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [0, 3]  ########State########  Sensemaking
# Initial Length:  1 2
#
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [0, 4]  ########State########  Sensemaking
# Initial Length:  1 1
#
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [0, 5]  ########State########  Sensemaking
# Initial Length:  1 0
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# already calculated
# already calculated
# Roi Cycles: ####################### [1, 2]  ########State########  Sensemaking
# Initial Length:  2 1
#
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [1, 3]  ########State########  Sensemaking
# Initial Length:  2 2
#
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [1, 4]  ########State########  Sensemaking
# Initial Length:  2 1
#
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [1, 5]  ########State########  Sensemaking
# Initial Length:  2 0
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [2, 3]  ########State########  Sensemaking
# Initial Length:  1 2
#
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [2, 4]  ########State########  Sensemaking
# Initial Length:  1 1
#
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [2, 5]  ########State########  Sensemaking
# Initial Length:  1 0
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [3, 4]  ########State########  Sensemaking
# Initial Length:  2 1
#
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [3, 5]  ########State########  Sensemaking
# Initial Length:  2 0
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [4, 5]  ########State########  Sensemaking
# Initial Length:  1 0
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [0, 1]  ########State########  Foraging
# Initial Length:  5 2
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.46871658244620706
# Roi Cycles: ####################### [0, 2]  ########State########  Foraging
# Initial Length:  5 4
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.8668152851274225
# Roi Cycles: ####################### [0, 3]  ########State########  Foraging
# Initial Length:  5 6
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.8922951180849767
# Roi Cycles: ####################### [0, 4]  ########State########  Foraging
# Initial Length:  5 3
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.6962703401140228
# Roi Cycles: ####################### [0, 5]  ########State########  Foraging
# Initial Length:  5 2
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.7518296340458492
# already calculated
# already calculated
# Roi Cycles: ####################### [1, 2]  ########State########  Foraging
# Initial Length:  2 4
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.583882420770365
# Roi Cycles: ####################### [1, 3]  ########State########  Foraging
# Initial Length:  2 6
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.38273308888522595
# Roi Cycles: ####################### [1, 4]  ########State########  Foraging
# Initial Length:  2 3
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.746885633390364
# Roi Cycles: ####################### [1, 5]  ########State########  Foraging
# Initial Length:  2 2
#
# State is:  Foraging   MWUT Result is:   Not Enough Data
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [2, 3]  ########State########  Foraging
# Initial Length:  4 6
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.7609067270751141
# Roi Cycles: ####################### [2, 4]  ########State########  Foraging
# Initial Length:  4 3
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.8254979107046321
# Roi Cycles: ####################### [2, 5]  ########State########  Foraging
# Initial Length:  4 2
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.7236736098317631
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [3, 4]  ########State########  Foraging
# Initial Length:  6 3
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.5958830905651777
# Roi Cycles: ####################### [3, 5]  ########State########  Foraging
# Initial Length:  6 2
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.7728299926844475
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [4, 5]  ########State########  Foraging
# Initial Length:  3 2
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.6830913983096087
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [0, 1]  ########State########  Navigation
# Initial Length:  0 6
# State is:  Navigation   MWUT Result Non-Stationarity:   True 0.0018205326093252568
# Roi Cycles: ####################### [0, 2]  ########State########  Navigation
# Initial Length:  0 12
# State is:  Navigation   MWUT Result Non-Stationarity:   True 1.0011806007956517e-05
# Roi Cycles: ####################### [0, 3]  ########State########  Navigation
# Initial Length:  0 14
# State is:  Navigation   MWUT Result Non-Stationarity:   True 1.4714605647231172e-06
# Roi Cycles: ####################### [0, 4]  ########State########  Navigation
# Initial Length:  0 12
# State is:  Navigation   MWUT Result Non-Stationarity:   True 9.223801659863749e-06
# Roi Cycles: ####################### [0, 5]  ########State########  Navigation
# Initial Length:  0 3
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.05934643879191985
# already calculated
# already calculated
# Roi Cycles: ####################### [1, 2]  ########State########  Navigation
# Initial Length:  6 12
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.06200321841588671
# Roi Cycles: ####################### [1, 3]  ########State########  Navigation
# Initial Length:  6 14
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.25887869615249515
# Roi Cycles: ####################### [1, 4]  ########State########  Navigation
# Initial Length:  6 12
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.21611244474067448
# Roi Cycles: ####################### [1, 5]  ########State########  Navigation
# Initial Length:  6 3
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.5958830905651777
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [2, 3]  ########State########  Navigation
# Initial Length:  12 14
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.06967939874859642
# Roi Cycles: ####################### [2, 4]  ########State########  Navigation
# Initial Length:  12 12
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.2748968059725133
# Roi Cycles: ####################### [2, 5]  ########State########  Navigation
# Initial Length:  12 3
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.7130177613662307
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [3, 4]  ########State########  Navigation
# Initial Length:  14 12
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.5032994276013005
# Roi Cycles: ####################### [3, 5]  ########State########  Navigation
# Initial Length:  14 3
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.9469353082452422
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [4, 5]  ########State########  Navigation
# Initial Length:  12 3
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.9393012261935498
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# ########################### data/NDSI-2D\taskname_ndsi-2d-task_userid_72a8d170-77ae-400e-b2a5-de9e1d33a714.csv
# already calculated
# Roi Cycles: ####################### [0, 1]  ########State########  Sensemaking
# Initial Length:  2 3
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [0, 2]  ########State########  Sensemaking
# Initial Length:  2 1
#
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [0, 3]  ########State########  Sensemaking
# Initial Length:  2 2
#
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [0, 4]  ########State########  Sensemaking
# Initial Length:  2 1
#
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [0, 5]  ########State########  Sensemaking
# Initial Length:  2 2
#
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [0, 6]  ########State########  Sensemaking
# Initial Length:  2 1
#
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# already calculated
# already calculated
# Roi Cycles: ####################### [1, 2]  ########State########  Sensemaking
# Initial Length:  3 1
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [1, 3]  ########State########  Sensemaking
# Initial Length:  3 2
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [1, 4]  ########State########  Sensemaking
# Initial Length:  3 1
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [1, 5]  ########State########  Sensemaking
# Initial Length:  3 2
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [1, 6]  ########State########  Sensemaking
# Initial Length:  3 1
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [2, 3]  ########State########  Sensemaking
# Initial Length:  1 2
#
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [2, 4]  ########State########  Sensemaking
# Initial Length:  1 1
#
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [2, 5]  ########State########  Sensemaking
# Initial Length:  1 2
#
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [2, 6]  ########State########  Sensemaking
# Initial Length:  1 1
#
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [3, 4]  ########State########  Sensemaking
# Initial Length:  2 1
#
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [3, 5]  ########State########  Sensemaking
# Initial Length:  2 2
#
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [3, 6]  ########State########  Sensemaking
# Initial Length:  2 1
#
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [4, 5]  ########State########  Sensemaking
# Initial Length:  1 2
#
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [4, 6]  ########State########  Sensemaking
# Initial Length:  1 1
#
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [5, 6]  ########State########  Sensemaking
# Initial Length:  2 1
#
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [0, 1]  ########State########  Foraging
# Initial Length:  6 1
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.11899072089312354
# Roi Cycles: ####################### [0, 2]  ########State########  Foraging
# Initial Length:  6 3
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.5958830905651777
# Roi Cycles: ####################### [0, 3]  ########State########  Foraging
# Initial Length:  6 0
# State is:  Foraging   MWUT Result Non-Stationarity:   True 0.0018205326093252568
# Roi Cycles: ####################### [0, 4]  ########State########  Foraging
# Initial Length:  6 2
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.38273308888522595
# Roi Cycles: ####################### [0, 5]  ########State########  Foraging
# Initial Length:  6 6
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [0, 6]  ########State########  Foraging
# Initial Length:  6 8
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.832239946617841
# already calculated
# already calculated
# Roi Cycles: ####################### [1, 2]  ########State########  Foraging
# Initial Length:  1 3
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.3457785861511603
# Roi Cycles: ####################### [1, 3]  ########State########  Foraging
# Initial Length:  1 0
# State is:  Foraging   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [1, 4]  ########State########  Foraging
# Initial Length:  1 2
#
# State is:  Foraging   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [1, 5]  ########State########  Foraging
# Initial Length:  1 6
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.11899072089312354
# Roi Cycles: ####################### [1, 6]  ########State########  Foraging
# Initial Length:  1 8
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.06343142528861123
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [2, 3]  ########State########  Foraging
# Initial Length:  3 0
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.05934643879191985
# Roi Cycles: ####################### [2, 4]  ########State########  Foraging
# Initial Length:  3 2
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.746885633390364
# Roi Cycles: ####################### [2, 5]  ########State########  Foraging
# Initial Length:  3 6
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.5958830905651777
# Roi Cycles: ####################### [2, 6]  ########State########  Foraging
# Initial Length:  3 8
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.44910223297552876
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [3, 4]  ########State########  Foraging
# Initial Length:  0 2
# State is:  Foraging   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [3, 5]  ########State########  Foraging
# Initial Length:  0 6
# State is:  Foraging   MWUT Result Non-Stationarity:   True 0.0018205326093252568
# Roi Cycles: ####################### [3, 6]  ########State########  Foraging
# Initial Length:  0 8
# State is:  Foraging   MWUT Result Non-Stationarity:   True 0.00020537573614121685
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [4, 5]  ########State########  Foraging
# Initial Length:  2 6
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.38273308888522595
# Roi Cycles: ####################### [4, 6]  ########State########  Foraging
# Initial Length:  2 8
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.2635524772829727
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [5, 6]  ########State########  Foraging
# Initial Length:  6 8
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.832239946617841
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [0, 1]  ########State########  Navigation
# Initial Length:  3 9
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.8479574434396122
# Roi Cycles: ####################### [0, 2]  ########State########  Navigation
# Initial Length:  3 8
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.6745880506934296
# Roi Cycles: ####################### [0, 3]  ########State########  Navigation
# Initial Length:  3 1
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.3457785861511603
# Roi Cycles: ####################### [0, 4]  ########State########  Navigation
# Initial Length:  3 8
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.9145412891236006
# Roi Cycles: ####################### [0, 5]  ########State########  Navigation
# Initial Length:  3 7
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [0, 6]  ########State########  Navigation
# Initial Length:  3 7
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.7234279091104521
# already calculated
# already calculated
# Roi Cycles: ####################### [1, 2]  ########State########  Navigation
# Initial Length:  9 8
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.378470101810532
# Roi Cycles: ####################### [1, 3]  ########State########  Navigation
# Initial Length:  9 1
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.15859438902379297
# Roi Cycles: ####################### [1, 4]  ########State########  Navigation
# Initial Length:  9 8
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.882183376147296
# Roi Cycles: ####################### [1, 5]  ########State########  Navigation
# Initial Length:  9 7
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.8275243855621697
# Roi Cycles: ####################### [1, 6]  ########State########  Navigation
# Initial Length:  9 7
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.30629043736267414
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [2, 3]  ########State########  Navigation
# Initial Length:  8 1
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.1716304569198689
# Roi Cycles: ####################### [2, 4]  ########State########  Navigation
# Initial Length:  8 8
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.5182820298149953
# Roi Cycles: ####################### [2, 5]  ########State########  Navigation
# Initial Length:  8 7
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.6782958016068641
# Roi Cycles: ####################### [2, 6]  ########State########  Navigation
# Initial Length:  8 7
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.8141697337422555
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [3, 4]  ########State########  Navigation
# Initial Length:  1 8
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.1661445267950824
# Roi Cycles: ####################### [3, 5]  ########State########  Navigation
# Initial Length:  1 7
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.17971249487899976
# Roi Cycles: ####################### [3, 6]  ########State########  Navigation
# Initial Length:  1 7
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.1877812720991524
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [4, 5]  ########State########  Navigation
# Initial Length:  8 7
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.9043154028270174
# Roi Cycles: ####################### [4, 6]  ########State########  Navigation
# Initial Length:  8 7
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.3740916318694725
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [5, 6]  ########State########  Navigation
# Initial Length:  7 7
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.5115517707912103
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# ########################### data/NDSI-2D\taskname_ndsi-2d-task_userid_733a1ac5-0b01-485e-9b29-ac33932aa240.csv
# already calculated
# Roi Cycles: ####################### [0, 1]  ########State########  Sensemaking
# Initial Length:  2 16
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [0, 2]  ########State########  Sensemaking
# Initial Length:  2 2
#
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# already calculated
# already calculated
# Roi Cycles: ####################### [1, 2]  ########State########  Sensemaking
# Initial Length:  16 2
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [0, 1]  ########State########  Foraging
# Initial Length:  1 0
# State is:  Foraging   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [0, 2]  ########State########  Foraging
# Initial Length:  1 7
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.08647626549366563
# already calculated
# already calculated
# Roi Cycles: ####################### [1, 2]  ########State########  Foraging
# Initial Length:  0 7
# State is:  Foraging   MWUT Result Non-Stationarity:   True 0.0006067668456360628
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [0, 1]  ########State########  Navigation
# Initial Length:  2 7
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.31623268726570686
# Roi Cycles: ####################### [0, 2]  ########State########  Navigation
# Initial Length:  2 6
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.8635475816959237
# already calculated
# already calculated
# Roi Cycles: ####################### [1, 2]  ########State########  Navigation
# Initial Length:  7 6
#
# State is:  Navigation   MWUT Result Non-Stationarity:   True 0.041382898277857925
# already calculated
# already calculated
# already calculated
# ########################### data/NDSI-2D\taskname_ndsi-2d-task_userid_7d014c75-453b-4188-9e4e-fb086984896a.csv
# already calculated
# Roi Cycles: ####################### [0, 1]  ########State########  Sensemaking
# Initial Length:  1 11
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [0, 2]  ########State########  Sensemaking
# Initial Length:  1 12
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [0, 3]  ########State########  Sensemaking
# Initial Length:  1 3
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [0, 4]  ########State########  Sensemaking
# Initial Length:  1 3
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [0, 5]  ########State########  Sensemaking
# Initial Length:  1 6
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [0, 6]  ########State########  Sensemaking
# Initial Length:  1 16
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [0, 7]  ########State########  Sensemaking
# Initial Length:  1 1
#
# State is:  Sensemaking   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [0, 8]  ########State########  Sensemaking
# Initial Length:  1 6
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [0, 9]  ########State########  Sensemaking
# Initial Length:  1 6
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [0, 10]  ########State########  Sensemaking
# Initial Length:  1 7
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# already calculated
# already calculated
# Roi Cycles: ####################### [1, 2]  ########State########  Sensemaking
# Initial Length:  11 12
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [1, 3]  ########State########  Sensemaking
# Initial Length:  11 3
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [1, 4]  ########State########  Sensemaking
# Initial Length:  11 3
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [1, 5]  ########State########  Sensemaking
# Initial Length:  11 6
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [1, 6]  ########State########  Sensemaking
# Initial Length:  11 16
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [1, 7]  ########State########  Sensemaking
# Initial Length:  11 1
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [1, 8]  ########State########  Sensemaking
# Initial Length:  11 6
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [1, 9]  ########State########  Sensemaking
# Initial Length:  11 6
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [1, 10]  ########State########  Sensemaking
# Initial Length:  11 7
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [2, 3]  ########State########  Sensemaking
# Initial Length:  12 3
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [2, 4]  ########State########  Sensemaking
# Initial Length:  12 3
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [2, 5]  ########State########  Sensemaking
# Initial Length:  12 6
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [2, 6]  ########State########  Sensemaking
# Initial Length:  12 16
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [2, 7]  ########State########  Sensemaking
# Initial Length:  12 1
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [2, 8]  ########State########  Sensemaking
# Initial Length:  12 6
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [2, 9]  ########State########  Sensemaking
# Initial Length:  12 6
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [2, 10]  ########State########  Sensemaking
# Initial Length:  12 7
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [3, 4]  ########State########  Sensemaking
# Initial Length:  3 3
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [3, 5]  ########State########  Sensemaking
# Initial Length:  3 6
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [3, 6]  ########State########  Sensemaking
# Initial Length:  3 16
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [3, 7]  ########State########  Sensemaking
# Initial Length:  3 1
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [3, 8]  ########State########  Sensemaking
# Initial Length:  3 6
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [3, 9]  ########State########  Sensemaking
# Initial Length:  3 6
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [3, 10]  ########State########  Sensemaking
# Initial Length:  3 7
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [4, 5]  ########State########  Sensemaking
# Initial Length:  3 6
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [4, 6]  ########State########  Sensemaking
# Initial Length:  3 16
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [4, 7]  ########State########  Sensemaking
# Initial Length:  3 1
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [4, 8]  ########State########  Sensemaking
# Initial Length:  3 6
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [4, 9]  ########State########  Sensemaking
# Initial Length:  3 6
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [4, 10]  ########State########  Sensemaking
# Initial Length:  3 7
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [5, 6]  ########State########  Sensemaking
# Initial Length:  6 16
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [5, 7]  ########State########  Sensemaking
# Initial Length:  6 1
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [5, 8]  ########State########  Sensemaking
# Initial Length:  6 6
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [5, 9]  ########State########  Sensemaking
# Initial Length:  6 6
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [5, 10]  ########State########  Sensemaking
# Initial Length:  6 7
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [6, 7]  ########State########  Sensemaking
# Initial Length:  16 1
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [6, 8]  ########State########  Sensemaking
# Initial Length:  16 6
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [6, 9]  ########State########  Sensemaking
# Initial Length:  16 6
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [6, 10]  ########State########  Sensemaking
# Initial Length:  16 7
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [7, 8]  ########State########  Sensemaking
# Initial Length:  1 6
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [7, 9]  ########State########  Sensemaking
# Initial Length:  1 6
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [7, 10]  ########State########  Sensemaking
# Initial Length:  1 7
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [8, 9]  ########State########  Sensemaking
# Initial Length:  6 6
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [8, 10]  ########State########  Sensemaking
# Initial Length:  6 7
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [9, 10]  ########State########  Sensemaking
# Initial Length:  6 7
#
# State is:  Sensemaking   MWUT Result Non-Stationarity:   False 1.0
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [0, 1]  ########State########  Foraging
# Initial Length:  21 11
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.10287856895637114
# Roi Cycles: ####################### [0, 2]  ########State########  Foraging
# Initial Length:  21 0
# State is:  Foraging   MWUT Result Non-Stationarity:   True 6.820014035855273e-05
# Roi Cycles: ####################### [0, 3]  ########State########  Foraging
# Initial Length:  21 3
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.16226139993661481
# Roi Cycles: ####################### [0, 4]  ########State########  Foraging
# Initial Length:  21 4
#
# State is:  Foraging   MWUT Result Non-Stationarity:   True 0.03768194994604376
# ...
# Roi Cycles: ####################### [1, 5]  ########State########  Foraging
# Initial Length:  0 9
# State is:  Foraging   MWUT Result Non-Stationarity:   True 7.031069297129345e-05
# Roi Cycles: ####################### [1, 6]  ########State########  Foraging
# Initial Length:  0 6
# State is:  Foraging   MWUT Result Non-Stationarity:   True 0.0018205326093252568
# Roi Cycles: ####################### [1, 7]  ########State########  Foraging
# Initial Length:  0 3
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.05934643879191985
# Roi Cycles: ####################### [1, 8]  ########State########  Foraging
# Initial Length:  0 12
# State is:  Foraging   MWUT Result Non-Stationarity:   True 2.952437008237853e-06
# Roi Cycles: ####################### [1, 9]  ########State########  Foraging
# Initial Length:  0 2
# State is:  Foraging   MWUT Result is:   Not Enough Data
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [2, 3]  ########State########  Foraging
# Initial Length:  0 2
# State is:  Foraging   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [2, 4]  ########State########  Foraging
# Initial Length:  0 2
# State is:  Foraging   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [2, 5]  ########State########  Foraging
# Initial Length:  0 9
# State is:  Foraging   MWUT Result Non-Stationarity:   True 7.031069297129345e-05
# Roi Cycles: ####################### [2, 6]  ########State########  Foraging
# Initial Length:  0 6
# State is:  Foraging   MWUT Result Non-Stationarity:   True 0.0018205326093252568
# Roi Cycles: ####################### [2, 7]  ########State########  Foraging
# Initial Length:  0 3
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.05934643879191985
# Roi Cycles: ####################### [2, 8]  ########State########  Foraging
# Initial Length:  0 12
# State is:  Foraging   MWUT Result Non-Stationarity:   True 2.952437008237853e-06
# Roi Cycles: ####################### [2, 9]  ########State########  Foraging
# Initial Length:  0 2
# State is:  Foraging   MWUT Result is:   Not Enough Data
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [3, 4]  ########State########  Foraging
# Initial Length:  2 2
#
# State is:  Foraging   MWUT Result is:   Not Enough Data
# Roi Cycles: ####################### [3, 5]  ########State########  Foraging
# Initial Length:  2 9
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.22109926355986897
# Roi Cycles: ####################### [3, 6]  ########State########  Foraging
# Initial Length:  2 6
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.38273308888522595
# Roi Cycles: ####################### [3, 7]  ########State########  Foraging
# Initial Length:  2 3
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.746885633390364
# Roi Cycles: ####################### [3, 8]  ########State########  Foraging
# Initial Length:  2 12
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.13416918012812584
# Roi Cycles: ####################### [3, 9]  ########State########  Foraging
# Initial Length:  2 2
#
# State is:  Foraging   MWUT Result is:   Not Enough Data
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [4, 5]  ########State########  Foraging
# Initial Length:  2 9
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.22109926355986897
# Roi Cycles: ####################### [4, 6]  ########State########  Foraging
# Initial Length:  2 6
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.38273308888522595
# Roi Cycles: ####################### [4, 7]  ########State########  Foraging
# Initial Length:  2 3
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.746885633390364
# Roi Cycles: ####################### [4, 8]  ########State########  Foraging
# Initial Length:  2 12
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.13416918012812584
# Roi Cycles: ####################### [4, 9]  ########State########  Foraging
# Initial Length:  2 2
#
# State is:  Foraging   MWUT Result is:   Not Enough Data
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [5, 6]  ########State########  Foraging
# Initial Length:  9 6
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.7650871933583798
# Roi Cycles: ####################### [5, 7]  ########State########  Foraging
# Initial Length:  9 3
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.3937686346429927
# Roi Cycles: ####################### [5, 8]  ########State########  Foraging
# Initial Length:  9 12
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.8343194288581393
# Roi Cycles: ####################### [5, 9]  ########State########  Foraging
# Initial Length:  9 2
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.22109926355986897
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [6, 7]  ########State########  Foraging
# Initial Length:  6 3
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.5958830905651777
# Roi Cycles: ####################### [6, 8]  ########State########  Foraging
# Initial Length:  6 12
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.6069054272179508
# Roi Cycles: ####################### [6, 9]  ########State########  Foraging
# Initial Length:  6 2
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.38273308888522595
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [7, 8]  ########State########  Foraging
# Initial Length:  3 12
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.2722535810629988
# Roi Cycles: ####################### [7, 9]  ########State########  Foraging
# Initial Length:  3 2
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.746885633390364
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [8, 9]  ########State########  Foraging
# Initial Length:  12 2
#
# State is:  Foraging   MWUT Result Non-Stationarity:   False 0.13416918012812584
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [0, 1]  ########State########  Navigation
# Initial Length:  7 7
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 1.0
# Roi Cycles: ####################### [0, 2]  ########State########  Navigation
# Initial Length:  7 11
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.7401354386035053
# Roi Cycles: ####################### [0, 3]  ########State########  Navigation
# Initial Length:  7 8
#
# State is:  Navigation   MWUT Result Non-Stationarity:   True 0.014273907248565159
# Roi Cycles: ####################### [0, 4]  ########State########  Navigation
# Initial Length:  7 8
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.11304872373174109
# Roi Cycles: ####################### [0, 5]  ########State########  Navigation
# Initial Length:  7 9
#
# State is:  Navigation   MWUT Result Non-Stationarity:   True 0.012867178823580412
# Roi Cycles: ####################### [0, 6]  ########State########  Navigation
# Initial Length:  7 5
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.08200998384950416
# Roi Cycles: ####################### [0, 7]  ########State########  Navigation
# Initial Length:  7 10
#
# State is:  Navigation   MWUT Result Non-Stationarity:   True 0.03017668941800584
# Roi Cycles: ####################### [0, 8]  ########State########  Navigation
# Initial Length:  7 6
#
# State is:  Navigation   MWUT Result Non-Stationarity:   True 0.041382898277857925
# Roi Cycles: ####################### [0, 9]  ########State########  Navigation
# Initial Length:  7 5
#
# State is:  Navigation   MWUT Result Non-Stationarity:   True 0.01856153230055051
# already calculated
# already calculated
# Roi Cycles: ####################### [1, 2]  ########State########  Navigation
# Initial Length:  7 11
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.7401354386035053
# Roi Cycles: ####################### [1, 3]  ########State########  Navigation
# Initial Length:  7 8
#
# State is:  Navigation   MWUT Result Non-Stationarity:   True 0.014273907248565159
# Roi Cycles: ####################### [1, 4]  ########State########  Navigation
# Initial Length:  7 8
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.11304872373174109
# Roi Cycles: ####################### [1, 5]  ########State########  Navigation
# Initial Length:  7 9
#
# State is:  Navigation   MWUT Result Non-Stationarity:   True 0.012867178823580412
# Roi Cycles: ####################### [1, 6]  ########State########  Navigation
# Initial Length:  7 5
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.08200998384950416
# Roi Cycles: ####################### [1, 7]  ########State########  Navigation
# Initial Length:  7 10
#
# State is:  Navigation   MWUT Result Non-Stationarity:   True 0.03017668941800584
# Roi Cycles: ####################### [1, 8]  ########State########  Navigation
# Initial Length:  7 6
#
# State is:  Navigation   MWUT Result Non-Stationarity:   True 0.041382898277857925
# Roi Cycles: ####################### [1, 9]  ########State########  Navigation
# Initial Length:  7 5
#
# State is:  Navigation   MWUT Result Non-Stationarity:   True 0.01856153230055051
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [2, 3]  ########State########  Navigation
# Initial Length:  11 8
#
# State is:  Navigation   MWUT Result Non-Stationarity:   True 0.0026390392059829847
# Roi Cycles: ####################### [2, 4]  ########State########  Navigation
# Initial Length:  11 8
#
# State is:  Navigation   MWUT Result Non-Stationarity:   True 0.037784107105590325
# Roi Cycles: ####################### [2, 5]  ########State########  Navigation
# Initial Length:  11 9
#
# State is:  Navigation   MWUT Result Non-Stationarity:   True 0.0015098417520521274
# Roi Cycles: ####################### [2, 6]  ########State########  Navigation
# Initial Length:  11 5
#
# State is:  Navigation   MWUT Result Non-Stationarity:   True 0.025585005116736385
# Roi Cycles: ####################### [2, 7]  ########State########  Navigation
# Initial Length:  11 10
#
# State is:  Navigation   MWUT Result Non-Stationarity:   True 0.0032556837077499555
# Roi Cycles: ####################### [2, 8]  ########State########  Navigation
# Initial Length:  11 6
#
# State is:  Navigation   MWUT Result Non-Stationarity:   True 0.010500359853868747
# Roi Cycles: ####################### [2, 9]  ########State########  Navigation
# Initial Length:  11 5
#
# State is:  Navigation   MWUT Result Non-Stationarity:   True 0.003821382547728744
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [3, 4]  ########State########  Navigation
# Initial Length:  8 8
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.23300651285105256
# Roi Cycles: ####################### [3, 5]  ########State########  Navigation
# Initial Length:  8 9
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.8078035282683297
# Roi Cycles: ####################### [3, 6]  ########State########  Navigation
# Initial Length:  8 5
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.6537973076475477
# Roi Cycles: ####################### [3, 7]  ########State########  Navigation
# Initial Length:  8 10
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.29927182623297655
# Roi Cycles: ####################### [3, 8]  ########State########  Navigation
# Initial Length:  8 6
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.6923653207923884
# Roi Cycles: ####################### [3, 9]  ########State########  Navigation
# Initial Length:  8 5
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.12013270946231565
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [4, 5]  ########State########  Navigation
# Initial Length:  8 9
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.30047788244599494
# Roi Cycles: ####################### [4, 6]  ########State########  Navigation
# Initial Length:  8 5
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.28038065000978973
# Roi Cycles: ####################### [4, 7]  ########State########  Navigation
# Initial Length:  8 10
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.7132023758678434
# Roi Cycles: ####################### [4, 8]  ########State########  Navigation
# Initial Length:  8 6
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.20015582985411084
# Roi Cycles: ####################### [4, 9]  ########State########  Navigation
# Initial Length:  8 5
#
# State is:  Navigation   MWUT Result Non-Stationarity:   True 0.04994963588614809
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [5, 6]  ########State########  Navigation
# Initial Length:  9 5
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.5888463705420549
# Roi Cycles: ####################### [5, 7]  ########State########  Navigation
# Initial Length:  9 10
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.3853680989973075
# Roi Cycles: ####################### [5, 8]  ########State########  Navigation
# Initial Length:  9 6
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.5905269690817421
# Roi Cycles: ####################### [5, 9]  ########State########  Navigation
# Initial Length:  9 5
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.09375771362679833
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [6, 7]  ########State########  Navigation
# Initial Length:  5 10
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.38175095126265657
# Roi Cycles: ####################### [6, 8]  ########State########  Navigation
# Initial Length:  5 6
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.8499863692282984
# Roi Cycles: ####################### [6, 9]  ########State########  Navigation
# Initial Length:  5 5
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.3946625491175668
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [7, 8]  ########State########  Navigation
# Initial Length:  10 6
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.26872542551891976
# Roi Cycles: ####################### [7, 9]  ########State########  Navigation
# Initial Length:  10 5
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.05498092989237109
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# Roi Cycles: ####################### [8, 9]  ########State########  Navigation
# Initial Length:  6 5
#
# State is:  Navigation   MWUT Result Non-Stationarity:   False 0.19504039754870217
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated
# already calculated

# %%
output_dataframe.head(20)
# Out:
#                                            User ROI_Cycle        State Result
# 0   userid_44968286-f204-4ad6-a9b5-d95b38e97866    [0, 1]  Sensemaking  False
# 1   userid_44968286-f204-4ad6-a9b5-d95b38e97866    [0, 2]  Sensemaking  False
# 2   userid_44968286-f204-4ad6-a9b5-d95b38e97866    [0, 3]  Sensemaking  False
# 3   userid_44968286-f204-4ad6-a9b5-d95b38e97866    [0, 4]  Sensemaking  False
# 4   userid_44968286-f204-4ad6-a9b5-d95b38e97866    [0, 5]  Sensemaking  False
# 5   userid_44968286-f204-4ad6-a9b5-d95b38e97866    [0, 6]  Sensemaking   True
# 6   userid_44968286-f204-4ad6-a9b5-d95b38e97866    [1, 2]  Sensemaking  False
# 7   userid_44968286-f204-4ad6-a9b5-d95b38e97866    [1, 3]  Sensemaking  False
# 8   userid_44968286-f204-4ad6-a9b5-d95b38e97866    [1, 4]  Sensemaking  False
# 9   userid_44968286-f204-4ad6-a9b5-d95b38e97866    [1, 5]  Sensemaking  False
# 10  userid_44968286-f204-4ad6-a9b5-d95b38e97866    [1, 6]  Sensemaking   True
# 11  userid_44968286-f204-4ad6-a9b5-d95b38e97866    [2, 3]  Sensemaking    NED
# 12  userid_44968286-f204-4ad6-a9b5-d95b38e97866    [2, 4]  Sensemaking    NED
# 13  userid_44968286-f204-4ad6-a9b5-d95b38e97866    [2, 5]  Sensemaking  False
# 14  userid_44968286-f204-4ad6-a9b5-d95b38e97866    [2, 6]  Sensemaking    NED
# 15  userid_44968286-f204-4ad6-a9b5-d95b38e97866    [3, 4]  Sensemaking    NED
# 16  userid_44968286-f204-4ad6-a9b5-d95b38e97866    [3, 5]  Sensemaking  False
# 17  userid_44968286-f204-4ad6-a9b5-d95b38e97866    [3, 6]  Sensemaking    NED
# 18  userid_44968286-f204-4ad6-a9b5-d95b38e97866    [4, 5]  Sensemaking  False
# 19  userid_44968286-f204-4ad6-a9b5-d95b38e97866    [4, 6]  Sensemaking    NED

# %%
output_dataframe.to_csv("data/NDSI-2D\\roi-manwhitneyresults.csv", index=False)
#output_dataframe.to_csv("data/NDSI-3D\\probability_distribution_roi_cycle_3d.csv", index=False)
