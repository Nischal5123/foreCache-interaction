# %%
import matplotlib.pyplot as plt

# Define the data
data = [
    # (Algorithm, Percentage, Accuracy)
    ("Win-Stay-Lose-Shift", "10%", 62),
    ("Win-Stay-Lose-Shift", "20%", 62),
    ("Win-Stay-Lose-Shift", "30%", 62),
    ("Win-Stay-Lose-Shift", "40%", 60),
    ("Win-Stay-Lose-Shift", "50%", 62),
    ("Win-Stay-Lose-Shift", "60%", 62),
    ("Win-Stay-Lose-Shift", "70%", 56),
    ("Win-Stay-Lose-Shift", "80%", 56),
    ("Win-Stay-Lose-Shift", "90%", 58),
    ("E-Greedy", "10%", 52),
    ("E-Greedy", "20%", 54),
    ("E-Greedy", "30%", 52),
    ("E-Greedy", "40%", 50),
    ("E-Greedy", "50%", 51),
    ("E-Greedy", "60%", 51),
    ("E-Greedy", "70%", 55),
    ("E-Greedy", "80%", 51),
    ("E-Greedy", "90%", 52),
    ("Greedy", "10%", 28),
    ("Greedy", "20%", 29),
    ("Greedy", "30%", 35),
    ("Greedy", "40%", 32),
    ("Greedy", "50%", 30),
    ("Greedy", "60%", 32),
    ("Greedy", "70%", 25),
    ("Greedy", "80%", 17),
    ("Greedy", "90%", 11),
    ("Adaptive E-Greedy", "10%", 52),
    ("Adaptive E-Greedy", "20%", 49),
    ("Adaptive E-Greedy", "30%", 49),
    ("Adaptive E-Greedy", "40%", 42),
    ("Adaptive E-Greedy", "50%", 49),
    ("Adaptive E-Greedy", "60%", 40),
    ("Adaptive E-Greedy", "70%", 46),
    ("Adaptive E-Greedy", "80%", 46),
    ("Adaptive E-Greedy", "90%", 35),
    ("Random", "10%", 25),
    ("Random", "20%", 25),
    ("Random", "30%", 25),
    ("Random", "40%", 25),
    ("Random", "50%", 25),
    ("Random", "60%", 25),
    ("Random", "70%", 25),
    ("Random", "80%", 25),
    ("Random", "90%", 25),
    ("Mortal Bandit", "10%", 24),
    ("Mortal Bandit", "20%", 32),
    ("Mortal Bandit", "30%", 30),
    ("Mortal Bandit", "40%", 32),
    ("Mortal Bandit", "50%", 34),
    ("Mortal Bandit", "60%", 35),
    ("Mortal Bandit", "70%", 36),
    ("Mortal Bandit", "80%", 35),
    ("Mortal Bandit", "90%", 42),
    ("E-Greedy with E-Decay", "10%", 51),
    ("E-Greedy with E-Decay", "20%", 54),
    ("E-Greedy with E-Decay", "30%", 52),
    ("E-Greedy with E-Decay", "40%", 50),
    ("E-Greedy with E-Decay", "50%", 51),
    ("E-Greedy with E-Decay", "60%", 51),
    ("E-Greedy with E-Decay", "70%", 55),
    ("E-Greedy with E-Decay", "80%", 51),
    ("E-Greedy with E-Decay", "90%", 52),
]

# Separate the data by algorithm
algorithms = {}
for entry in data:
    algorithm, percentage, accuracy = entry
    if algorithm not in algorithms:
        algorithms[algorithm] = {"x": [], "y": [], "label": algorithm}
    algorithms[algorithm]["x"].append(percentage)
    algorithms[algorithm]["y"].append(accuracy)

# %%
algorithms['Random']
# Out:
# {'x': ['10%', '20%', '30%', '40%', '50%', '60%', '70%', '80%', '90%'],
#  'y': [25, 25, 25, 25, 25, 25, 25, 25, 25],
#  'label': 'Random'}

# %%
# Create a plot for each algorithm
for algorithm, values in algorithms.items():
    plt.plot(values["x"], values["y"], marker='o', label=algorithm)

# Customize the plot
plt.xlabel("Percentage of data used for training")
plt.ylabel("Accuracy (%)")
plt.title("Algorithm Accuracy vs. Percentage")
plt.legend(loc="best")

# Show the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
markers = ['o', 's', 'D', '^', 'v', '<', '>', 'p', '*', 'H', '+', 'x']

# %%
idx = 0
for algorithm, values in algorithms.items():
    plt.plot(values["x"], values["y"], marker=markers[idx], label=algorithm)
    idx += 1

# Customize the plot
plt.xlabel("Percentage of data used for training")
plt.ylabel("Accuracy (%)")
plt.ylim(ymin=0)
# plt.title("Algorithm Accuracy vs. Percentage")
plt.legend(loc="upper center", bbox_to_anchor=(0.5, -0.15), ncol=3)

# Show the plot
plt.grid(axis='y')
# plt.tight_layout()
plt.show()
plt.savefig("imMens_accuracy_faa.pdf")

# %%
import matplotlib.pyplot as plt

# Define the data
data = [
    ("Win-Stay-Lose-Shift", "10%", 58),
    ("Win-Stay-Lose-Shift", "20%", 56),
    ("Win-Stay-Lose-Shift", "30%", 55),
    ("Win-Stay-Lose-Shift", "40%", 56),
    ("Win-Stay-Lose-Shift", "50%", 54),
    ("Win-Stay-Lose-Shift", "60%", 52),
    ("Win-Stay-Lose-Shift", "70%", 52),
    ("Win-Stay-Lose-Shift", "80%", 50),
    ("Win-Stay-Lose-Shift", "90%", 47),
    ("Greedy", "10%", 64),
    ("Greedy", "20%", 62),
    ("Greedy", "30%", 60),
    ("Greedy", "40%", 60),
    ("Greedy", "50%", 66),
    ("Greedy", "60%", 63),
    ("Greedy", "70%", 61),
    ("Greedy", "80%", 62),
    ("Greedy", "90%", 66),
    ("E-Greedy with E-Decay", "10%", 67),
    ("E-Greedy with E-Decay", "20%", 64),
    ("E-Greedy with E-Decay", "30%", 65),
    ("E-Greedy with E-Decay", "40%", 65),
    ("E-Greedy with E-Decay", "50%", 64),
    ("E-Greedy with E-Decay", "60%", 63),
    ("E-Greedy with E-Decay", "70%", 60),
    ("E-Greedy with E-Decay", "80%", 56),
    ("E-Greedy with E-Decay", "90%", 55),
    ("E-Greedy", "10%", 66),
    ("E-Greedy", "20%", 64),
    ("E-Greedy", "30%", 65),
    ("E-Greedy", "40%", 64),
    ("E-Greedy", "50%", 64),
    ("E-Greedy", "60%", 62),
    ("E-Greedy", "70%", 60),
    ("E-Greedy", "80%", 56),
    ("E-Greedy", "90%", 56),
    ("Adaptive E-Greedy", "10%", 63),
    ("Adaptive E-Greedy", "20%", 62),
    ("Adaptive E-Greedy", "30%", 56),
    ("Adaptive E-Greedy", "40%", 60),
    ("Adaptive E-Greedy", "50%", 59),
    ("Adaptive E-Greedy", "60%", 53),
    ("Adaptive E-Greedy", "70%", 49),
    ("Adaptive E-Greedy", "80%", 45),
    ("Adaptive E-Greedy", "90%", 48),
    ("Mortal Bandit", "10%", 25),
    ("Mortal Bandit", "20%", 24),
    ("Mortal Bandit", "30%", 27),
    ("Mortal Bandit", "40%", 29),
    ("Mortal Bandit", "50%", 27),
    ("Mortal Bandit", "60%", 29),
    ("Mortal Bandit", "70%", 30),
    ("Mortal Bandit", "80%", 30),
    ("Mortal Bandit", "90%", 32),
    ("Random", "10%", 25),
    ("Random", "20%", 25),
    ("Random", "30%", 25),
    ("Random", "40%", 25),
    ("Random", "50%", 25),
    ("Random", "60%", 25),
    ("Random", "70%", 25),
    ("Random", "80%", 25),
    ("Random", "90%", 25)
]

# Separate the data by algorithm
algorithms = {}
for entry in data:
    algorithm, percentage, accuracy = entry
    if algorithm not in algorithms:
        algorithms[algorithm] = {"x": [], "y": [], "label": algorithm}
    algorithms[algorithm]["x"].append(percentage)
    algorithms[algorithm]["y"].append(accuracy)

# %%
idx = 0
for algorithm, values in algorithms.items():
    plt.plot(values["x"], values["y"], marker=markers[idx], label=algorithm)
    idx += 1

# Customize the plot
plt.xlabel("Percentage of data used for training")
plt.ylabel("Accuracy (%)")
plt.ylim(ymin=0)
# plt.title("Algorithm Accuracy vs. Percentage")
plt.legend(loc="upper center", bbox_to_anchor=(0.5, -0.15), ncol=3)

# Show the plot
plt.grid(axis='y')
# plt.tight_layout()
plt.show()
plt.savefig("imMens_accuracy_brightkite.pdf")
