# %%
import pandas as pd
import ast

# Your CSV data
df = pd.read_csv("./data/zheng/competing_movies_interactions.csv")



# Initialize an empty DataFrame for the desired output
result_df = pd.DataFrame(columns=['index', 'user', 'interaction_session'])

# Iterate over rows of the original DataFrame
for _, row in df.iterrows():
    user = row['user']
    interaction_session = ast.literal_eval(row['interaction_session'])

    # Add rows to the result DataFrame
    for i, session_value in enumerate(interaction_session, start=1):
        result_df = pd.concat([result_df, pd.DataFrame({'index': [i], 'user': [user], 'interaction_session': [session_value]})], ignore_index=True)

# Save the result DataFrame to a CSV file without the default index
result_df.to_csv('./data/zheng/tableau_competing_movies_interactions.csv', index=False)

# %%
result_df.head()
# Out:
#   index               user interaction_session
# 0     1  stu31_ade_p3_logs                 334
# 1     2  stu31_ade_p3_logs                  45
# 2     3  stu31_ade_p3_logs                 334
# 3     4  stu31_ade_p3_logs                 331
# 4     5  stu31_ade_p3_logs                 334

# %%
import json
import pandas as pd
import numpy as np

# %%
def get_fields_from_vglstr(vglstr):
    encoding_str = vglstr.split(';')[1]
    encoding_str = encoding_str.split(':')[1]
    encodings = encoding_str.split(',')
    fields = []
    for encode in encodings:
        field = encode.split('-')[0]
        if field == '':
            continue
        fields.append(field)
    fields.sort()
    return fields

# %%
import os
import pandas as pd


user_interactions_path = './data/zheng/processed_csv/'
csv_files = os.listdir(user_interactions_path)

fieldnames = ['Title', 'US_Gross', 'Worldwide_Gross', 'US_DVD_Sales', 'Production_Budget', 'Release_Date', 'MPAA_Rating', 'Running_Time_min', 'Distributor', 'Source', 'Major_Genre', 'Creative_Type', 'Director', 'Rotten_Tomatoes_Rating', 'IMDB_Rating', 'IMDB_Votes']

for csv_filename in [csv_files[1]]:
    print("Converting '{}'...".format(csv_filename))
    user_name = csv_filename.split('.')[0]
    csv_path = os.path.join(user_interactions_path, csv_filename)

    df = pd.read_csv(csv_path)
    print('Total size of interaction log', len(df))

    df['Attribute'] = df['Value'].apply(lambda value: get_fields_from_vglstr(value) if pd.notna(value) else ['None'])
    df['User_Index'] = df.index  # Use the existing DataFrame index as User_Index

    df.to_csv(csv_path, index=False)
# Out:
# Converting 'pro13_ace_p3_logs.csv'...
# Total size of interaction log 1199
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[30], line 18
#      15 df = pd.read_csv(csv_path)
#      16 print('Total size of interaction log', len(df))
# ---> 18 df['Attribute'] = df['Value'].apply(lambda value: get_fields_from_vglstr(value) if pd.notna(value) else ['None'])
#      19 df['User_Index'] = df.index  # Use the existing DataFrame index as User_Index
#      21 df.to_csv(csv_path, index=False)
#
# File ~/anaconda3/envs/ForeCache-Master/lib/python3.9/site-packages/pandas/core/series.py:4758, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4625 def apply(
#    4626     self,
#    4627     func: AggFuncType,
#    (...)
#    4632     **kwargs,
#    4633 ) -> DataFrame | Series:
#    4634     """
#    4635     Invoke function on values of Series.
#    4636
# ...

# %%
df_attributes
# Out:
# [['US_Gross'],
#  ['US_Gross'],
#  ['Title'],
#  ['Title'],
#  ['Title'],
#  ['Worldwide_Gross'],
#  ['Worldwide_Gross'],
#  ['Creative_Type', 'Worldwide_Gross'],
#  ['Creative_Type', 'Worldwide_Gross'],
#  ['Creative_Type', 'Director', 'Worldwide_Gross'],
#  ['Creative_Type', 'Director', 'Worldwide_Gross'],
#  ['Creative_Type', 'Worldwide_Gross'],
#  ['Creative_Type', 'Worldwide_Gross'],
#  ['Creative_Type', 'Distributor', 'Worldwide_Gross'],
#  ['Creative_Type', 'Distributor', 'Worldwide_Gross'],
#  ['Creative_Type', 'Worldwide_Gross'],
#  ['Creative_Type', 'Worldwide_Gross'],
#  ['Creative_Type', 'Distributor', 'Worldwide_Gross'],
#  ['Creative_Type', 'Distributor', 'Worldwide_Gross'],
#  ['Creative_Type', 'Distributor', 'Worldwide_Gross'],
#  ['Creative_Type', 'Distributor', 'Worldwide_Gross'],
#  ['Creative_Type', 'Distributor', 'Worldwide_Gross'],
#  ['Creative_Type', 'Distributor', 'Worldwide_Gross'],
#  ['Creative_Type', 'Worldwide_Gross'],
# ...
